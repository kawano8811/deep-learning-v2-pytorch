# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for review, label in tqdm(zip(reviews, labels)):
    if label == 'POSITIVE':
        positive_counts += Counter(review.split(' '))
    elif label == 'NEGATIVE':
        negative_counts += Counter(review.split(' '))
    total_counts += Counter(review.split(' '))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 608904),
#  ('the', 191890),
#  ('.', 176457),
#  ('and', 99137),
#  ('a', 92602),
#  ('of', 85130),
#  ('to', 73753),
#  ('is', 63115),
#  ('in', 55323),
#  ('br', 54644),
#  ('it', 53157),
#  ('i', 45013),
#  ('that', 39440),
#  ('this', 38755),
#  ('s', 37166),
#  ('as', 29019),
#  ('with', 25603),
#  ('for', 24672),
#  ('was', 24267),
#  ('film', 23122),
#  ('but', 22934),
#  ('movie', 21118),
#  ('his', 18822),
#  ('on', 18751),
#  ('you', 18478),
#  ('he', 17826),
#  ('are', 16524),
#  ('not', 15810),
#  ('t', 15191),
#  ('one', 15181),
#  ('have', 13934),
#  ('be', 13779),
#  ('all', 13261),
#  ('by', 13180),
#  ('who', 12673),
#  ('an', 12448),
#  ('at', 12413),
#  ('from', 11889),
#  ('her', 11443),
#  ('they', 11130),
#  ('has', 10170),
#  ('so', 10068),
#  ('like', 10002),
#  ('about', 9238),
#  ('very', 9163),
#  ('out', 9019),
#  ('there', 8933),
#  ('or', 8579),
#  ('what', 8570),
#  ('good', 8563),
#  ('she', 8472),
#  ('more', 8287),
#  ('some', 8228),
#  ('when', 8222),
#  ('if', 8055),
#  ('just', 7960),
#  ('can', 7732),
#  ('story', 7461),
#  ('time', 7223),
#  ('my', 7196),
#  ('well', 7106),
#  ('great', 7101),
#  ('up', 6986),
#  ('which', 6920),
#  ('their', 6834),
#  ('see', 6677),
#  ('we', 6164),
#  ('also', 6113),
#  ('really', 6000),
#  ('would', 5951),
#  ('will', 5746),
#  ('had', 5728),
#  ('only', 5689),
#  ('me', 5688),
#  ('him', 5504),
#  ('even', 5464),
#  ('most', 5426),
#  ('other', 5416),
#  ('were', 5361),
#  ('first', 5282),
#  ('than', 5196),
#  ('much', 5167),
#  ('its', 5097),
#  ('no', 5025),
#  ('into', 5023),
#  ('people', 4975),
#  ('best', 4771),
#  ('get', 4764),
#  ('love', 4746),
#  ('been', 4648),
#  ('how', 4631),
#  ('life', 4623),
#  ('because', 4533),
#  ('way', 4452),
#  ('do', 4333),
#  ('films', 4240),
#  ('them', 4210),
#  ('made', 4209),
#  ('two', 4198),
#  ('after', 4193),
#  ('many', 4144),
#  ('think', 4062),
#  ('too', 4052),
#  ('characters', 3996),
#  ('movies', 3964),
#  ('character', 3872),
#  ('show', 3871),
#  ('don', 3857),
#  ('watch', 3814),
#  ('man', 3778),
#  ('seen', 3765),
#  ('little', 3746),
#  ('still', 3734),
#  ('then', 3725),
#  ('make', 3638),
#  ('never', 3601),
#  ('could', 3594),
#  ('being', 3549),
#  ('where', 3524),
#  ('does', 3338),
#  ('over', 3329),
#  ('any', 3301),
#  ('while', 3220),
#  ('know', 3123),
#  ('ever', 3085),
#  ('years', 3068),
#  ('did', 3045),
#  ('here', 3015),
#  ('these', 2999),
#  ('end', 2947),
#  ('such', 2874),
#  ('real', 2833),
#  ('scene', 2832),
#  ('back', 2782),
#  ('new', 2768),
#  ('though', 2745),
#  ('those', 2736),
#  ('off', 2721),
#  ('world', 2716),
#  ('plot', 2715),
#  ('go', 2711),
#  ('acting', 2698),
#  ('your', 2695),
#  ('say', 2692),
#  ('scenes', 2679),
#  ('through', 2654),
#  ('better', 2643),
#  ('makes', 2632),
#  ('now', 2599),
#  ('ve', 2571),
#  ('work', 2555),
#  ('young', 2544),
#  ('old', 2538),
#  ('find', 2517),
#  ('both', 2504),
#  ('before', 2456),
#  ('series', 2418),
#  ('again', 2404),
#  ('quite', 2400),
#  ('should', 2371),
#  ('something', 2366),
#  ('cast', 2360),
#  ('us', 2359),
#  ('lot', 2351),
#  ('always', 2302),
#  ('another', 2299),
#  ('part', 2277),
#  ('actors', 2259),
#  ('family', 2253),
#  ('director', 2233),
#  ('own', 2233),
#  ('m', 2226),
#  ('between', 2198),
#  ('may', 2194),
#  ('every', 2187),
#  ('same', 2177),
#  ('funny', 2177),
#  ('watching', 2171),
#  ('bad', 2151),
#  ('role', 2147),
#  ('few', 2139),
#  ('doesn', 2135),
#  ('look', 2117),
#  ('performance', 2115),
#  ('re', 2076),
#  ('things', 2043),
#  ('times', 2032),
#  ('big', 2029),
#  ('why', 2020),
#  ('action', 2006),
#  ('however', 1998),
#  ('actually', 1993),
#  ('going', 1989),
#  ('comedy', 1940),
#  ('bit', 1939),
#  ('must', 1936),
#  ('down', 1932),
#  ('music', 1898),
#  ('take', 1892),
#  ('right', 1884),
#  ('long', 1879),
#  ('fact', 1878),
#  ('saw', 1872),
#  ('didn', 1865),
#  ('fun', 1862),
#  ('excellent', 1857),
#  ('around', 1857),
#  ('without', 1851),
#  ('thing', 1848),
#  ('each', 1834),
#  ('got', 1816),
#  ('thought', 1803),
#  ('day', 1791),
#  ('feel', 1778),
#  ('come', 1770),
#  ('seems', 1758),
#  ('beautiful', 1751),
#  ('done', 1750),
#  ('especially', 1741),
#  ('pretty', 1739),
#  ('almost', 1732),
#  ('want', 1732),
#  ('give', 1730),
#  ('last', 1725),
#  ('played', 1709),
#  ('yet', 1699),
#  ('different', 1681),
#  ('since', 1681),
#  ('true', 1679),
#  ('although', 1663),
#  ('gets', 1658),
#  ('interesting', 1651),
#  ('job', 1634),
#  ('horror', 1614),
#  ('enough', 1602),
#  ('our', 1590),
#  ('shows', 1579),
#  ('woman', 1574),
#  ('tv', 1549),
#  ('probably', 1538),
#  ('original', 1524),
#  ('plays', 1518),
#  ('point', 1516),
#  ('course', 1515),
#  ('girl', 1512),
#  ('wonderful', 1509),
#  ('john', 1504),
#  ('far', 1492),
#  ('nothing', 1483),
#  ('ll', 1471),
#  ('rather', 1463),
#  ('father', 1463),
#  ('isn', 1460),
#  ('dvd', 1459),
#  ('d', 1454),
#  ('later', 1452),
#  ('once', 1451),
#  ('whole', 1445),
#  ('away', 1443),
#  ('hard', 1442),
#  ('together', 1435),
#  ('found', 1434),
#  ('war', 1425),
#  ('year', 1422),
#  ('set', 1417),
#  ('screen', 1417),
#  ('having', 1411),
#  ('am', 1411),
#  ('place', 1403),
#  ('making', 1399),
#  ('comes', 1399),
#  ('sure', 1393),
#  ('might', 1393),
#  ('perfect', 1385),
#  ('performances', 1380),
#  ('kind', 1378),
#  ('american', 1375),
#  ('takes', 1368),
#  ('three', 1355),
#  ('worth', 1354),
#  ('everyone', 1352),
#  ('anyone', 1351),
#  ('himself', 1348),
#  ('play', 1348),
#  ('wife', 1332),
#  ('ending', 1318),
#  ('actor', 1317),
#  ('house', 1311),
#  ('classic', 1305),
#  ('goes', 1291),
#  ('everything', 1272),
#  ('book', 1260),
#  ('star', 1251),
#  ('enjoy', 1249),
#  ('version', 1242),
#  ('during', 1236),
#  ('nice', 1232),
#  ('least', 1232),
#  ('seeing', 1229),
#  ('put', 1220),
#  ('loved', 1214),
#  ('guy', 1211),
#  ('believe', 1206),
#  ('watched', 1205),
#  ('men', 1202),
#  ('amazing', 1193),
#  ('high', 1190),
#  ('anything', 1188),
#  ('night', 1186),
#  ('top', 1172),
#  ('definitely', 1165),
#  ('looking', 1160),
#  ('hollywood', 1160),
#  ('main', 1156),
#  ('episode', 1148),
#  ('gives', 1147),
#  ('second', 1142),
#  ('special', 1142),
#  ('seem', 1127),
#  ('sense', 1127),
#  ('fan', 1126),
#  ('home', 1124),
#  ('truly', 1123),
#  ('audience', 1119),
#  ('human', 1112),
#  ('mind', 1106),
#  ('recommend', 1106),
#  ('small', 1104),
#  ('along', 1103),
#  ('help', 1096),
#  ('short', 1093),
#  ('trying', 1092),
#  ('friends', 1084),
#  ('black', 1084),
#  ('full', 1078),
#  ('death', 1076),
#  ('script', 1076),
#  ('often', 1069),
#  ('heart', 1068),
#  ('favorite', 1064),
#  ('said', 1063),
#  ('live', 1062),
#  ('let', 1062),
#  ('today', 1060),
#  ('remember', 1060),
#  ('until', 1057),
#  ('left', 1048),
#  ('maybe', 1040),
#  ('less', 1038),
#  ('early', 1038),
#  ('become', 1035),
#  ('liked', 1027),
#  ('brilliant', 1023),
#  ('moments', 1023),
#  ('others', 1020),
#  ('won', 1018),
#  ('shot', 1005),
#  ('women', 1001),
#  ('came', 1000),
#  ('lives', 998),
#  ('looks', 996),
#  ('used', 990),
#  ('effects', 985),
#  ('mother', 983),
#  ('highly', 982),
#  ('cinema', 981),
#  ('read', 979),
#  ('style', 976),
#  ('enjoyed', 974),
#  ('stars', 972),
#  ('perhaps', 965),
#  ('given', 964),
#  ('drama', 963),
#  ('line', 957),
#  ('boy', 950),
#  ('next', 949),
#  ('need', 947),
#  ('playing', 946),
#  ('entertaining', 945),
#  ('use', 944),
#  ('overall', 936),
#  ('fine', 936),
#  ('mr', 934),
#  ('dark', 934),
#  ('someone', 931),
#  ('works', 930),
#  ('picture', 928),
#  ('kids', 925),
#  ('certainly', 920),
#  ('simply', 919),
#  ('couple', 917),
#  ('minutes', 917),
#  ('friend', 915),
#  ('wasn', 914),
#  ('keep', 914),
#  ('children', 914),
#  ('face', 900),
#  ('finally', 897),
#  ('against', 897),
#  ('lost', 892),
#  ('history', 888),
#  ('understand', 885),
#  ('else', 882),
#  ('throughout', 882),
#  ('michael', 882),
#  ('rest', 881),
#  ('city', 880),
#  ('son', 877),
#  ('several', 875),
#  ('reason', 873),
#  ('fans', 867),
#  ('production', 867),
#  ('written', 866),
#  ('based', 863),
#  ('hope', 856),
#  ('dead', 853),
#  ('try', 853),
#  ('strong', 846),
#  ('tell', 839),
#  ('start', 838),
#  ('school', 837),
#  ('money', 836),
#  ('white', 836),
#  ('genre', 835),
#  ('itself', 832),
#  ('past', 831),
#  ('half', 826),
#  ('idea', 823),
#  ('late', 821),
#  ('sometimes', 819),
#  ('beginning', 819),
#  ('final', 819),
#  ('game', 808),
#  ('case', 807),
#  ('able', 806),
#  ('despite', 806),
#  ('camera', 805),
#  ('person', 804),
#  ('becomes', 804),
#  ('yes', 801),
#  ('humor', 801),
#  ('art', 798),
#  ('stories', 798),
#  ('side', 796),
#  ('completely', 796),
#  ('town', 791),
#  ('soon', 788),
#  ('child', 783),
#  ('viewer', 783),
#  ('getting', 781),
#  ('instead', 779),
#  ('under', 778),
#  ('felt', 774),
#  ('video', 767),
#  ('james', 766),
#  ('roles', 765),
#  ('days', 755),
#  ('wrong', 755),
#  ('either', 752),
#  ('simple', 751),
#  ('wants', 750),
#  ('turns', 749),
#  ('doing', 748),
#  ('age', 747),
#  ('close', 746),
#  ('episodes', 746),
#  ('name', 742),
#  ('budget', 733),
#  ('title', 729),
#  ('fantastic', 727),
#  ('evil', 725),
#  ('went', 724),
#  ('piece', 721),
#  ('called', 720),
#  ('turn', 720),
#  ('eyes', 716),
#  ('head', 716),
#  ('direction', 714),
#  ('relationship', 713),
#  ('david', 711),
#  ('musical', 711),
#  ('absolutely', 708),
#  ('experience', 707),
#  ('lead', 706),
#  ('sort', 706),
#  ('parts', 705),
#  ('jack', 704),
#  ('sex', 701),
#  ('directed', 699),
#  ('living', 693),
#  ('known', 693),
#  ('behind', 692),
#  ('including', 689),
#  ('themselves', 689),
#  ('lines', 688),
#  ('actress', 687),
#  ('feeling', 686),
#  ('documentary', 686),
#  ('brother', 686),
#  ('example', 685),
#  ('oscar', 684),
#  ('murder', 684),
#  ('low', 682),
#  ('chance', 680),
#  ('ago', 676),
#  ('already', 674),
#  ('moving', 674),
#  ('moment', 672),
#  ('season', 671),
#  ('reality', 670),
#  ('told', 670),
#  ('supporting', 669),
#  ('score', 667),
#  ('hit', 667),
#  ('voice', 666),
#  ('dialogue', 666),
#  ('hilarious', 665),
#  ('matter', 663),
#  ('quality', 661),
#  ('hand', 656),
#  ('released', 655),
#  ('romantic', 655),
#  ('fight', 654),
#  ('enjoyable', 654),
#  ('happy', 654),
#  ('future', 652),
#  ('gave', 651),
#  ('finds', 650),
#  ('king', 649),
#  ('entire', 649),
#  ('light', 649),
#  ('song', 648),
#  ('police', 646),
#  ('daughter', 646),
#  ('number', 645),
#  ('paul', 644),
#  ('sound', 643),
#  ('expect', 642),
#  ('type', 642),
#  ('laugh', 642),
#  ('husband', 641),
#  ('coming', 639),
#  ('view', 638),
#  ('cinematography', 636),
#  ('particularly', 634),
#  ('shown', 631),
#  ('took', 631),
#  ('whose', 627),
#  ('events', 625),
#  ('modern', 625),
#  ('mean', 625),
#  ('wanted', 621),
#  ('superb', 620),
#  ('somewhat', 618),
#  ('important', 616),
#  ('run', 615),
#  ('leave', 615),
#  ('etc', 615),
#  ('heard', 614),
#  ('totally', 613),
#  ('country', 612),
#  ('self', 612),
#  ('change', 611),
#  ('tells', 611),
#  ('english', 611),
#  ('career', 607),
#  ('greatest', 606),
#  ('british', 605),
#  ('violence', 604),
#  ('miss', 603),
#  ('guys', 603),
#  ('york', 601),
#  ('robert', 601),
#  ('usual', 598),
#  ('killer', 597),
#  ('starts', 594),
#  ('thriller', 591),
#  ('girls', 591),
#  ('television', 591),
#  ('care', 590),
#  ('opinion', 589),
#  ('easy', 586),
#  ('realistic', 582),
#  ('tale', 580),
#  ('says', 579),
#  ('extremely', 578),
#  ('problem', 574),
#  ('comic', 571),
#  ('writing', 571),
#  ('ones', 570),
#  ('power', 569),
#  ('rock', 569),
#  ('writer', 567),
#  ('songs', 567),
#  ('attention', 566),
#  ('act', 565),
#  ('alone', 561),
#  ('novel', 561),
#  ('involved', 560),
#  ('french', 558),
#  ('stuff', 558),
#  ('hero', 557),
#  ('kid', 557),
#  ('animation', 557),
#  ('taken', 556),
#  ('seemed', 553),
#  ('eye', 553),
#  ('strange', 552),
#  ('wish', 552),
#  ('four', 551),
#  ('sad', 550),
#  ('atmosphere', 548),
#  ('class', 547),
#  ('serious', 546),
#  ('god', 545),
#  ('cool', 542),
#  ('happened', 541),
#  ('o', 541),
#  ('team', 539),
#  ('perfectly', 539),
#  ('ways', 537),
#  ('kill', 536),
#  ('begins', 536),
#  ('b', 536),
#  ('taking', 535),
#  ('due', 534),
#  ('beauty', 534),
#  ('surprised', 534),
#  ('knows', 534),
#  ('order', 533),
#  ('sequence', 533),
#  ('richard', 533),
#  ('similar', 532),
#  ('cannot', 532),
#  ('opening', 531),
#  ('exactly', 531),
#  ('theme', 531),
#  ('george', 530),
#  ('society', 530),
#  ('powerful', 530),
#  ('room', 529),
#  ('joe', 529),
#  ('famous', 529),
#  ('entertainment', 528),
#  ('problems', 528),
#  ('myself', 527),
#  ('car', 527),
#  ('across', 526),
#  ('memorable', 526),
#  ('anyway', 526),
#  ('herself', 525),
#  ('release', 524),
#  ('tries', 524),
#  ('level', 524),
#  ('among', 523),
#  ('happen', 523),
#  ('unique', 520),
#  ('easily', 518),
#  ('stop', 516),
#  ('ends', 516),
#  ('sets', 515),
#  ('slow', 515),
#  ('thinking', 515),
#  ('message', 514),
#  ('interest', 514),
#  ('crime', 512),
#  ('upon', 511),
#  ('believable', 510),
#  ('sister', 509),
#  ('brought', 507),
#  ('lady', 506),
#  ('viewing', 506),
#  ('viewers', 505),
#  ('certain', 504),
#  ('within', 504),
#  ('flick', 504),
#  ('bring', 504),
#  ('tony', 503),
#  ('form', 502),
#  ('happens', 501),
#  ('working', 501),
#  ('whether', 501),
#  ('local', 501),
#  ('above', 500),
#  ('group', 500),
#  ('mostly', 499),
#  ('knew', 498),
#  ('possible', 498),
#  ('mystery', 497),
#  ('romance', 497),
#  ('nature', 496),
#  ('parents', 496),
#  ('meets', 495),
#  ('emotional', 495),
#  ('soundtrack', 495),
#  ('couldn', 495),
#  ('follow', 494),
#  ('middle', 494),
#  ('usually', 493),
#  ('red', 492),
#  ('killed', 491),
#  ('dance', 489),
#  ('major', 487),
#  ('haven', 487),
#  ('dream', 484),
#  ('words', 482),
#  ('named', 481),
#  ('peter', 480),
#  ('obviously', 480),
#  ('period', 479),
#  ('huge', 479),
#  ('needs', 478),
#  ('th', 478),
#  ('blood', 477),
#  ('masterpiece', 476),
#  ('typical', 475),
#  ('stand', 475),
#  ('tom', 474),
#  ('guess', 473),
#  ('yourself', 472),
#  ('particular', 472),
#  ('de', 472),
#  ('feature', 471),
#  ('earth', 470),
#  ('talent', 470),
#  ('leads', 470),
#  ('fantasy', 470),
#  ('deal', 469),
#  ('elements', 468),
#  ('disney', 468),
#  ('five', 467),
#  ('america', 467),
#  ('personal', 466),
#  ('fast', 466),
#  ('started', 465),
#  ('running', 464),
#  ('brings', 463),
#  ('stage', 461),
#  ('street', 460),
#  ('poor', 460),
#  ('incredible', 459),
#  ('unfortunately', 459),
#  ('cut', 458),
#  ('jane', 458),
#  ('showing', 457),
#  ('turned', 456),
#  ('giving', 455),
#  ('deep', 454),
#  ('truth', 454),
#  ('hours', 453),
#  ('near', 452),
#  ('indeed', 452),
#  ('nearly', 452),
#  ('surprise', 451),
#  ('clearly', 450),
#  ('became', 449),
#  ('japanese', 448),
#  ('hour', 446),
#  ('rating', 446),
#  ('sweet', 446),
#  ('obvious', 445),
#  ('feels', 445),
#  ('era', 445),
#  ('talking', 444),
#  ('body', 443),
#  ('clear', 441),
#  ('female', 440),
#  ('situation', 439),
#  ('lots', 439),
#  ('meet', 438),
#  ('except', 438),
#  ('keeps', 437),
#  ('learn', 437),
#  ('means', 436),
#  ('comments', 434),
#  ('eventually', 433),
#  ('complete', 433),
#  ('note', 433),
#  ('sequences', 431),
#  ('bill', 431),
#  ('fall', 430),
#  ('buy', 429),
#  ('filmed', 428),
#  ('ten', 427),
#  ('shots', 427),
#  ('older', 427),
#  ('recommended', 425),
#  ('unlike', 424),
#  ('hell', 424),
#  ('william', 423),
#  ('difficult', 423),
#  ('general', 422),
#  ('suspense', 421),
#  ('check', 421),
#  ('gone', 420),
#  ('doubt', 419),
#  ('plenty', 419),
#  ('present', 419),
#  ('beyond', 419),
#  ('appears', 418),
#  ('business', 418),
#  ('subject', 418),
#  ('dramatic', 417),
#  ('talk', 417),
#  ('match', 417),
#  ('wonder', 416),
#  ('forget', 415),
#  ('third', 414),
#  ('fi', 413),
#  ('baby', 413),
#  ('earlier', 412),
#  ('portrayal', 411),
#  ('points', 411),
#  ('sci', 411),
#  ('single', 411),
#  ('whom', 411),
#  ('scary', 410),
#  ('using', 409),
#  ('leaves', 408),
#  ('add', 408),
#  ('oh', 406),
#  ('solid', 405),
#  ('call', 405),
#  ('hear', 404),
#  ('wouldn', 403),
#  ('beautifully', 403),
#  ('brothers', 402),
#  ('lee', 402),
#  ('recently', 401),
#  ('word', 401),
#  ('jim', 400),
#  ('jokes', 399),
#  ('space', 399),
#  ('move', 398),
#  ('adventure', 398),
#  ('married', 398),
#  ('lack', 398),
#  ('non', 397),
#  ('setting', 397),
#  ('straight', 397),
#  ('touching', 396),
#  ('awesome', 396),
#  ('falls', 396),
#  ('figure', 396),
#  ('success', 396),
#  ('political', 396),
#  ('stewart', 395),
#  ('aren', 393),
#  ('return', 393),
#  ('features', 393),
#  ('sees', 392),
#  ('theater', 392),
#  ('battle', 391),
#  ('please', 389),
#  ('terrific', 389),
#  ('dog', 389),
#  ('social', 387),
#  ('portrayed', 385),
#  ('sexual', 385),
#  ('outstanding', 385),
#  ('die', 385),
#  ('effective', 385),
#  ('rich', 384),
#  ('actual', 384),
#  ('boys', 384),
#  ('leading', 383),
#  ('various', 383),
#  ('dr', 382),
#  ('decent', 380),
#  ('towards', 379),
#  ('hate', 379),
#  ('none', 378),
#  ('interested', 377),
#  ('subtle', 377),
#  ('creepy', 376),
#  ('disappointed', 376),
#  ('mark', 376),
#  ('screenplay', 375),
#  ('pace', 375),
#  ('ben', 374),
#  ('inside', 374),
#  ('boring', 374),
#  ('popular', 372),
#  ('acted', 372),
#  ('caught', 371),
#  ('looked', 370),
#  ('basically', 370),
#  ('cold', 369),
#  ('intelligent', 369),
#  ('directors', 368),
#  ('storyline', 368),
#  ('open', 368),
#  ('crazy', 368),
#  ('moves', 367),
#  ('realize', 367),
#  ('deserves', 367),
#  ('western', 366),
#  ('manages', 366),
#  ('rare', 365),
#  ('familiar', 364),
#  ('appreciate', 364),
#  ('harry', 364),
#  ('impressive', 363),
#  ('rate', 363),
#  ('charming', 363),
#  ('singing', 363),
#  ('review', 362),
#  ('supposed', 362),
#  ('magic', 362),
#  ('mention', 362),
#  ('animated', 362),
#  ('language', 361),
#  ('journey', 361),
#  ('background', 361),
#  ('reading', 360),
#  ('noir', 360),
#  ('century', 359),
#  ('visual', 359),
#  ('male', 359),
#  ('material', 359),
#  ('natural', 359),
#  ('mary', 359),
#  ('imagine', 358),
#  ('pure', 357),
#  ('effect', 357),
#  ('smith', 357),
#  ('stunning', 357),
#  ('saying', 356),
#  ('kept', 356),
#  ('hot', 356),
#  ('created', 356),
#  ('escape', 355),
#  ('dancing', 355),
#  ('secret', 354),
#  ('question', 353),
#  ('office', 353),
#  ('complex', 353),
#  ('somehow', 353),
#  ('stay', 352),
#  ('spirit', 352),
#  ('seriously', 352),
#  ('master', 351),
#  ('kelly', 350),
#  ('copy', 349),
#  ('uses', 349),
#  ('free', 348),
#  ('create', 348),
#  ('telling', 348),
#  ('air', 348),
#  ('adult', 347),
#  ('plus', 346),
#  ('expected', 345),
#  ('hands', 345),
#  ('apart', 345),
#  ('wait', 345),
#  ('recent', 343),
#  ('average', 343),
#  ('following', 343),
#  ('members', 341),
#  ('co', 341),
#  ('thanks', 341),
#  ('attempt', 341),
#  ('quickly', 341),
#  ('ok', 341),
#  ('previous', 340),
#  ('frank', 340),
#  ('reviews', 339),
#  ('edge', 339),
#  ('worked', 339),
#  ('scott', 338),
#  ('exciting', 338),
#  ('surprisingly', 338),
#  ('follows', 337),
#  ('filled', 337),
#  ('public', 337),
#  ('themes', 337),
#  ('e', 337),
#  ('needed', 336),
#  ('images', 335),
#  ('minute', 335),
#  ('laughs', 335),
#  ('touch', 334),
#  ('outside', 334),
#  ('missed', 333),
#  ('fighting', 332),
#  ('lovely', 332),
#  ('admit', 331),
#  ('large', 331),
#  ('successful', 331),
#  ('casting', 330),
#  ('genius', 330),
#  ('break', 329),
#  ('band', 329),
#  ('reasons', 329),
#  ('comment', 329),
#  ('odd', 328),
#  ('gore', 328),
#  ('hold', 328),
#  ('studio', 328),
#  ('violent', 328),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 617942),
#  ('.', 185250),
#  ('the', 179948),
#  ('a', 87270),
#  ('and', 81714),
#  ('to', 76045),
#  ('of', 75910),
#  ('br', 57915),
#  ('is', 55097),
#  ('it', 53296),
#  ('i', 52118),
#  ('in', 48140),
#  ('this', 45171),
#  ('that', 41559),
#  ('s', 34626),
#  ('was', 29127),
#  ('movie', 27704),
#  ('for', 24119),
#  ('but', 24001),
#  ('with', 22960),
#  ('as', 22699),
#  ('t', 22494),
#  ('film', 21077),
#  ('you', 19311),
#  ('on', 18920),
#  ('not', 18119),
#  ('have', 16766),
#  ('are', 16142),
#  ('be', 16059),
#  ('he', 15177),
#  ('one', 14469),
#  ('they', 14407),
#  ('at', 13516),
#  ('all', 13365),
#  ('his', 13364),
#  ('so', 12711),
#  ('like', 12426),
#  ('there', 11792),
#  ('just', 11666),
#  ('by', 11625),
#  ('or', 11317),
#  ('an', 11306),
#  ('who', 10991),
#  ('from', 10731),
#  ('if', 10475),
#  ('about', 10007),
#  ('out', 9869),
#  ('what', 9321),
#  ('some', 9118),
#  ('no', 8975),
#  ('her', 8655),
#  ('even', 8497),
#  ('can', 8447),
#  ('has', 8321),
#  ('bad', 8259),
#  ('good', 8234),
#  ('would', 7827),
#  ('up', 7638),
#  ('only', 7509),
#  ('more', 7403),
#  ('when', 7400),
#  ('she', 7014),
#  ('really', 6938),
#  ('time', 6879),
#  ('had', 6811),
#  ('my', 6687),
#  ('were', 6666),
#  ('very', 6355),
#  ('which', 6345),
#  ('me', 6194),
#  ('see', 6022),
#  ('we', 5865),
#  ('don', 5840),
#  ('their', 5794),
#  ('do', 5775),
#  ('story', 5768),
#  ('than', 5669),
#  ('much', 5611),
#  ('been', 5598),
#  ('get', 5527),
#  ('because', 5463),
#  ('people', 5284),
#  ('then', 5222),
#  ('make', 5215),
#  ('how', 5207),
#  ('could', 5194),
#  ('any', 5131),
#  ('into', 5000),
#  ('made', 4992),
#  ('first', 4748),
#  ('well', 4711),
#  ('other', 4674),
#  ('them', 4626),
#  ('plot', 4609),
#  ('too', 4578),
#  ('movies', 4519),
#  ('acting', 4501),
#  ('will', 4449),
#  ('way', 4419),
#  ('most', 4311),
#  ('him', 4237),
#  ('after', 4234),
#  ('think', 4022),
#  ('its', 4016),
#  ('characters', 3972),
#  ('also', 3936),
#  ('watch', 3928),
#  ('did', 3909),
#  ('off', 3899),
#  ('character', 3873),
#  ('why', 3840),
#  ('being', 3725),
#  ('know', 3691),
#  ('better', 3689),
#  ('seen', 3638),
#  ('over', 3627),
#  ('ever', 3622),
#  ('never', 3601),
#  ('where', 3572),
#  ('your', 3538),
#  ('two', 3457),
#  ('little', 3426),
#  ('films', 3378),
#  ('m', 3350),
#  ('here', 3304),
#  ('nothing', 3297),
#  ('say', 3293),
#  ('end', 3261),
#  ('should', 3244),
#  ('many', 3217),
#  ('something', 3208),
#  ('thing', 3174),
#  ('does', 3171),
#  ('show', 3155),
#  ('ve', 3128),
#  ('scene', 3127),
#  ('scenes', 3094),
#  ('these', 3048),
#  ('go', 2997),
#  ('didn', 2963),
#  ('great', 2931),
#  ('watching', 2901),
#  ('re', 2888),
#  ('doesn', 2858),
#  ('through', 2820),
#  ('such', 2812),
#  ('worst', 2793),
#  ('man', 2749),
#  ('actors', 2718),
#  ('while', 2685),
#  ('actually', 2678),
#  ('director', 2669),
#  ('back', 2654),
#  ('life', 2648),
#  ('funny', 2599),
#  ('going', 2566),
#  ('still', 2502),
#  ('look', 2495),
#  ('now', 2488),
#  ('another', 2470),
#  ('those', 2440),
#  ('old', 2426),
#  ('real', 2386),
#  ('minutes', 2379),
#  ('horror', 2377),
#  ('few', 2374),
#  ('before', 2368),
#  ('want', 2353),
#  ('love', 2342),
#  ('pretty', 2333),
#  ('same', 2306),
#  ('best', 2298),
#  ('script', 2293),
#  ('though', 2274),
#  ('every', 2233),
#  ('work', 2229),
#  ('least', 2199),
#  ('seems', 2191),
#  ('down', 2178),
#  ('enough', 2174),
#  ('guy', 2171),
#  ('got', 2151),
#  ('around', 2131),
#  ('part', 2115),
#  ('original', 2108),
#  ('find', 2077),
#  ('anything', 2072),
#  ('lot', 2062),
#  ('fact', 2053),
#  ('things', 2050),
#  ('isn', 2031),
#  ('new', 2030),
#  ('point', 2025),
#  ('again', 2022),
#  ('give', 2014),
#  ('thought', 1999),
#  ('d', 1987),
#  ('take', 1983),
#  ('makes', 1980),
#  ('whole', 1944),
#  ('years', 1944),
#  ('long', 1924),
#  ('however', 1915),
#  ('cast', 1889),
#  ('making', 1881),
#  ('gets', 1850),
#  ('big', 1850),
#  ('money', 1830),
#  ('might', 1821),
#  ('interesting', 1811),
#  ('far', 1800),
#  ('action', 1787),
#  ('right', 1783),
#  ('us', 1777),
#  ('come', 1776),
#  ('without', 1771),
#  ('almost', 1739),
#  ('awful', 1738),
#  ('ll', 1734),
#  ('quite', 1728),
#  ('reason', 1702),
#  ('must', 1696),
#  ('kind', 1695),
#  ('am', 1682),
#  ('done', 1676),
#  ('looks', 1673),
#  ('wasn', 1655),
#  ('comedy', 1654),
#  ('someone', 1649),
#  ('trying', 1640),
#  ('poor', 1638),
#  ('boring', 1637),
#  ('saw', 1633),
#  ('instead', 1631),
#  ('away', 1631),
#  ('probably', 1600),
#  ('girl', 1592),
#  ('sure', 1589),
#  ('looking', 1589),
#  ('believe', 1587),
#  ('maybe', 1575),
#  ('stupid', 1570),
#  ('anyone', 1568),
#  ('since', 1558),
#  ('world', 1541),
#  ('let', 1535),
#  ('last', 1534),
#  ('terrible', 1534),
#  ('tv', 1529),
#  ('times', 1522),
#  ('rather', 1520),
#  ('hard', 1514),
#  ('may', 1512),
#  ('waste', 1511),
#  ('effects', 1508),
#  ('between', 1508),
#  ('woman', 1495),
#  ('feel', 1492),
#  ('half', 1480),
#  ('book', 1461),
#  ('idea', 1446),
#  ('own', 1446),
#  ('young', 1443),
#  ('music', 1442),
#  ('sense', 1431),
#  ('bit', 1420),
#  ('having', 1408),
#  ('put', 1394),
#  ('found', 1394),
#  ('series', 1390),
#  ('worse', 1389),
#  ('goes', 1376),
#  ('role', 1371),
#  ('said', 1368),
#  ('main', 1356),
#  ('everything', 1334),
#  ('comes', 1329),
#  ('else', 1321),
#  ('screen', 1320),
#  ('either', 1315),
#  ('budget', 1314),
#  ('actor', 1310),
#  ('ending', 1310),
#  ('low', 1308),
#  ('supposed', 1307),
#  ('audience', 1306),
#  ('yet', 1304),
#  ('completely', 1299),
#  ('left', 1278),
#  ('wrong', 1278),
#  ('set', 1277),
#  ('always', 1276),
#  ('both', 1274),
#  ('shot', 1265),
#  ('course', 1264),
#  ('family', 1264),
#  ('watched', 1263),
#  ('seem', 1260),
#  ('place', 1259),
#  ('special', 1242),
#  ('simply', 1240),
#  ('day', 1237),
#  ('mean', 1226),
#  ('read', 1224),
#  ('three', 1206),
#  ('house', 1194),
#  ('oh', 1186),
#  ('dead', 1184),
#  ('year', 1184),
#  ('high', 1179),
#  ('camera', 1176),
#  ('less', 1175),
#  ('night', 1170),
#  ('horrible', 1168),
#  ('black', 1163),
#  ('once', 1161),
#  ('couldn', 1159),
#  ('worth', 1159),
#  ('our', 1153),
#  ('try', 1151),
#  ('video', 1142),
#  ('although', 1141),
#  ('line', 1129),
#  ('played', 1127),
#  ('rest', 1121),
#  ('dvd', 1118),
#  ('sex', 1114),
#  ('production', 1110),
#  ('fun', 1110),
#  ('everyone', 1101),
#  ('seeing', 1100),
#  ('mind', 1093),
#  ('during', 1087),
#  ('play', 1085),
#  ('version', 1078),
#  ('american', 1077),
#  ('kids', 1076),
#  ('given', 1075),
#  ('tell', 1075),
#  ('women', 1074),
#  ('used', 1066),
#  ('together', 1065),
#  ('second', 1058),
#  ('takes', 1050),
#  ('performance', 1049),
#  ('especially', 1047),
#  ('start', 1044),
#  ('use', 1043),
#  ('need', 1040),
#  ('each', 1039),
#  ('dialogue', 1038),
#  ('doing', 1036),
#  ('wife', 1035),
#  ('lines', 1031),
#  ('star', 1025),
#  ('unfortunately', 1021),
#  ('problem', 1020),
#  ('himself', 1013),
#  ('fan', 1013),
#  ('name', 1011),
#  ('crap', 1010),
#  ('couple', 1003),
#  ('help', 999),
#  ('killer', 996),
#  ('getting', 994),
#  ('death', 992),
#  ('guess', 982),
#  ('head', 980),
#  ('piece', 979),
#  ('seemed', 967),
#  ('short', 963),
#  ('different', 963),
#  ('nice', 962),
#  ('entire', 959),
#  ('later', 955),
#  ('john', 944),
#  ('next', 943),
#  ('school', 940),
#  ('hollywood', 937),
#  ('person', 937),
#  ('true', 934),
#  ('home', 932),
#  ('absolutely', 932),
#  ('shows', 929),
#  ('felt', 925),
#  ('understand', 923),
#  ('care', 921),
#  ('plays', 920),
#  ('written', 919),
#  ('sort', 913),
#  ('decent', 907),
#  ('job', 904),
#  ('men', 904),
#  ('flick', 902),
#  ('until', 901),
#  ('stars', 899),
#  ('title', 898),
#  ('went', 894),
#  ('face', 893),
#  ('yes', 893),
#  ('case', 892),
#  ('called', 891),
#  ('along', 888),
#  ('perhaps', 880),
#  ('friends', 879),
#  ('wanted', 878),
#  ('itself', 877),
#  ('writing', 877),
#  ('hour', 870),
#  ('evil', 865),
#  ('full', 863),
#  ('annoying', 861),
#  ('came', 860),
#  ('ridiculous', 860),
#  ('top', 858),
#  ('tries', 857),
#  ('laugh', 850),
#  ('direction', 848),
#  ('guys', 848),
#  ('keep', 842),
#  ('playing', 842),
#  ('totally', 837),
#  ('god', 835),
#  ('won', 834),
#  ('example', 827),
#  ('obviously', 825),
#  ('lost', 822),
#  ('attempt', 822),
#  ('save', 822),
#  ('already', 822),
#  ('gore', 820),
#  ('except', 815),
#  ('thinking', 814),
#  ('car', 814),
#  ('ok', 808),
#  ('blood', 808),
#  ('sound', 807),
#  ('b', 804),
#  ('truly', 803),
#  ('act', 800),
#  ('white', 800),
#  ('kill', 799),
#  ('war', 799),
#  ('moments', 792),
#  ('father', 788),
#  ('finally', 782),
#  ('style', 780),
#  ('remember', 779),
#  ('turn', 777),
#  ('cheap', 768),
#  ('please', 767),
#  ('quality', 765),
#  ('wouldn', 765),
#  ('lack', 762),
#  ('dull', 761),
#  ('looked', 760),
#  ('lead', 755),
#  ('recommend', 754),
#  ('kid', 750),
#  ('enjoy', 750),
#  ('seriously', 748),
#  ('boy', 748),
#  ('starts', 746),
#  ('stuff', 741),
#  ('run', 739),
#  ('hope', 738),
#  ('myself', 738),
#  ('children', 738),
#  ('hell', 737),
#  ('etc', 735),
#  ('beginning', 735),
#  ('none', 734),
#  ('killed', 728),
#  ('lame', 728),
#  ('girls', 727),
#  ('under', 726),
#  ('behind', 725),
#  ('wonder', 725),
#  ('episode', 724),
#  ('slow', 723),
#  ('hand', 722),
#  ('against', 722),
#  ('others', 722),
#  ('obvious', 721),
#  ('small', 720),
#  ('avoid', 715),
#  ('picture', 714),
#  ('complete', 713),
#  ('based', 712),
#  ('poorly', 710),
#  ('early', 705),
#  ('becomes', 704),
#  ('cut', 703),
#  ('anyway', 703),
#  ('writer', 702),
#  ('predictable', 701),
#  ('close', 700),
#  ('mother', 700),
#  ('fans', 700),
#  ('classic', 698),
#  ('apparently', 697),
#  ('happens', 696),
#  ('become', 696),
#  ('self', 696),
#  ('cannot', 694),
#  ('gave', 694),
#  ('certainly', 694),
#  ('despite', 693),
#  ('several', 689),
#  ('live', 689),
#  ('often', 686),
#  ('saying', 679),
#  ('silly', 676),
#  ('stop', 676),
#  ('mr', 675),
#  ('jokes', 671),
#  ('overall', 667),
#  ('human', 665),
#  ('expect', 664),
#  ('scary', 664),
#  ('liked', 662),
#  ('happened', 662),
#  ('friend', 660),
#  ('wants', 654),
#  ('entertaining', 652),
#  ('cinema', 649),
#  ('beautiful', 647),
#  ('final', 647),
#  ('performances', 646),
#  ('bunch', 645),
#  ('eyes', 643),
#  ('child', 641),
#  ('themselves', 640),
#  ('involved', 639),
#  ('call', 635),
#  ('daughter', 632),
#  ('badly', 632),
#  ('days', 632),
#  ('says', 631),
#  ('hours', 631),
#  ('actress', 630),
#  ('heard', 630),
#  ('running', 625),
#  ('art', 625),
#  ('fight', 625),
#  ('turns', 625),
#  ('humor', 625),
#  ('directed', 623),
#  ('happen', 623),
#  ('body', 622),
#  ('interest', 621),
#  ('disappointed', 620),
#  ('viewer', 620),
#  ('sorry', 618),
#  ('shots', 617),
#  ('basically', 617),
#  ('violence', 617),
#  ('hero', 616),
#  ('group', 614),
#  ('talking', 612),
#  ('yourself', 610),
#  ('leave', 608),
#  ('rating', 607),
#  ('side', 607),
#  ('throughout', 606),
#  ('single', 606),
#  ('extremely', 605),
#  ('type', 605),
#  ('word', 605),
#  ('possible', 603),
#  ('mess', 602),
#  ('parts', 602),
#  ('review', 602),
#  ('dark', 600),
#  ('game', 600),
#  ('gives', 599),
#  ('started', 599),
#  ('weak', 598),
#  ('took', 597),
#  ('alone', 594),
#  ('aren', 593),
#  ('effort', 592),
#  ('michael', 591),
#  ('able', 591),
#  ('non', 590),
#  ('unless', 588),
#  ('usually', 587),
#  ('female', 586),
#  ('matter', 586),
#  ('definitely', 584),
#  ('drama', 583),
#  ('turned', 581),
#  ('police', 580),
#  ('son', 579),
#  ('exactly', 579),
#  ('voice', 579),
#  ('past', 575),
#  ('talent', 575),
#  ('tried', 574),
#  ('zombie', 574),
#  ('feeling', 569),
#  ('town', 569),
#  ('five', 567),
#  ('huge', 565),
#  ('genre', 563),
#  ('soon', 563),
#  ('middle', 562),
#  ('sequel', 561),
#  ('serious', 559),
#  ('cool', 558),
#  ('history', 557),
#  ('earth', 555),
#  ('opening', 554),
#  ('ends', 554),
#  ('straight', 553),
#  ('dialog', 549),
#  ('beyond', 546),
#  ('wasted', 544),
#  ('particularly', 544),
#  ('major', 544),
#  ('level', 543),
#  ('coming', 543),
#  ('rent', 541),
#  ('lives', 539),
#  ('sad', 539),
#  ('stories', 539),
#  ('editing', 536),
#  ('moment', 534),
#  ('joke', 534),
#  ('clearly', 534),
#  ('taken', 532),
#  ('fast', 531),
#  ('premise', 531),
#  ('minute', 529),
#  ('across', 528),
#  ('order', 528),
#  ('okay', 528),
#  ('dumb', 527),
#  ('mostly', 523),
#  ('stay', 522),
#  ('late', 522),
#  ('mention', 521),
#  ('fails', 520),
#  ('die', 518),
#  ('talk', 517),
#  ('falls', 517),
#  ('hit', 516),
#  ('theater', 514),
#  ('storyline', 514),
#  ('write', 514),
#  ('pointless', 513),
#  ('novel', 513),
#  ('wish', 512),
#  ('fine', 508),
#  ('sometimes', 507),
#  ('known', 505),
#  ('room', 505),
#  ('whatever', 504),
#  ('ten', 503),
#  ('husband', 503),
#  ('career', 501),
#  ('appears', 501),
#  ('sit', 500),
#  ('words', 500),
#  ('taking', 499),
#  ('told', 494),
#  ('total', 492),
#  ('english', 490),
#  ('shown', 489),
#  ('monster', 487),
#  ('killing', 487),
#  ('ones', 487),
#  ('lee', 486),
#  ('using', 486),
#  ('imdb', 486),
#  ('chance', 486),
#  ('living', 486),
#  ('add', 483),
#  ('brother', 483),
#  ('murder', 482),
#  ('power', 482),
#  ('somehow', 482),
#  ('actual', 482),
#  ('giving', 481),
#  ('knew', 480),
#  ('kept', 480),
#  ('four', 480),
#  ('usual', 478),
#  ('hate', 477),
#  ('strange', 476),
#  ('material', 475),
#  ('possibly', 473),
#  ('number', 472),
#  ('problems', 470),
#  ('flat', 470),
#  ('easily', 470),
#  ('works', 469),
#  ('points', 469),
#  ('opinion', 469),
#  ('imagine', 467),
#  ('roles', 467),
#  ('ago', 465),
#  ('reviews', 465),
#  ('nudity', 465),
#  ('age', 465),
#  ('local', 465),
#  ('due', 464),
#  ('decided', 463),
#  ('including', 462),
#  ('writers', 461),
#  ('plain', 460),
#  ('feels', 459),
#  ('experience', 458),
#  ('near', 457),
#  ('king', 456),
#  ('lots', 455),
#  ('somewhat', 455),
#  ('class', 452),
#  ('needs', 451),
#  ('otherwise', 450),
#  ('change', 450),
#  ('score', 450),
#  ('knows', 450),
#  ('city', 449),
#  ('credits', 448),
#  ('pathetic', 448),
#  ('bring', 447),
#  ('cop', 447),
#  ('wait', 447),
#  ('space', 447),
#  ('upon', 447),
#  ('cinematography', 446),
#  ('cheesy', 446),
#  ('shame', 445),
#  ('whether', 445),
#  ('zombies', 444),
#  ('entertainment', 443),
#  ('song', 443),
#  ('lady', 443),
#  ('nor', 442),
#  ('doubt', 442),
#  ('whose', 441),
#  ('expected', 440),
#  ('average', 439),
#  ('songs', 438),
#  ('comments', 437),
#  ('bored', 436),
#  ('figure', 435),
#  ('nearly', 435),
#  ('released', 435),
#  ('james', 434),
#  ('laughable', 434),
#  ('needed', 433),
#  ('sets', 433),
#  ('robert', 432),
#  ('o', 431),
#  ('check', 431),
#  ('footage', 430),
#  ('excellent', 430),
#  ('potential', 430),
#  ('attention', 429),
#  ('free', 428),
#  ('ask', 427),
#  ('general', 426),
#  ('sequence', 426),
#  ('stand', 425),
#  ('forced', 425),
#  ('view', 424),
#  ('development', 423),
#  ('garbage', 422),
#  ('light', 421),
#  ('documentary', 420),
#  ('above', 418),
#  ('mystery', 418),
#  ('within', 417),
#  ('george', 416),
#  ('clear', 416),
#  ('buy', 416),
#  ('comic', 415),
#  ('trash', 414),
#  ('important', 414),
#  ('begin', 413),
#  ('reading', 412),
#  ('directing', 411),
#  ('spent', 411),
#  ('musical', 411),
#  ('hilarious', 410),
#  ('move', 410),
#  ('hear', 410),
#  ('television', 410),
#  ('reality', 410),
#  ('thriller', 409),
#  ('means', 409),
#  ('male', 409),
#  ('pay', 409),
#  ('gone', 409),
#  ('forward', 409),
#  ('country', 408),
#  ('gay', 408),
#  ('haven', 408),
#  ('fall', 408),
#  ('hot', 407),
#  ('david', 407),
#  ('enjoyed', 406),
#  ('incredibly', 406),
#  ('fake', 406),
#  ('box', 405),
#  ('happy', 404),
#  ('filmed', 404),
#  ('named', 404),
#  ('laughs', 403),
#  ('forget', 402),
#  ('hardly', 402),
#  ('perfect', 402),
#  ('sounds', 402),
#  ('suspense', 401),
#  ('message', 401),
#  ('heart', 401),
#  ('british', 401),
#  ('weird', 400),
#  ('sequences', 398),
#  ('third', 397),
#  ('showing', 396),
#  ('cover', 396),
#  ('directors', 395),
#  ('eye', 395),
#  ('comment', 395),
#  ('sadly', 395),
#  ('failed', 393),
#  ('rock', 391),
#  ('sister', 391),
#  ('baby', 390),
#  ('feature', 390),
#  ('remake', 390),
#  ('question', 389),
#  ('events', 388),
#  ('miss', 388),
#  ('filmmakers', 387),
#  ('modern', 387),
#  ('finds', 385),
#  ('attempts', 384),
#  ('brain', 384),
#  ('spoilers', 384),
#  ('elements', 383),
#  ('screenplay', 382),
#  ('similar', 382),
#  ('loved', 381),
#  ('girlfriend', 380),
#  ('ideas', 379),
#  ('neither', 379),
#  ('tom', 379),
#  ('result', 379),
#  ('red', 378),
#  ('appear', 378),
#  ('crazy', 377),
#  ('worked', 377),
#  ('typical', 376),
#  ('sexual', 375),
#  ('working', 375),
#  ('barely', 374),
#  ('richard', 374),
#  ('air', 373),
#  ('leads', 373),
#  ('excuse', 372),
#  ('meant', 372),
#  ('viewers', 371),
#  ('unbelievable', 371),
#  ('plus', 370),
#  ('strong', 369),
#  ('theme', 369),
#  ('fire', 369),
#  ('gun', 369),
#  ('wrote', 367),
#  ('open', 367),
#  ('follow', 367),
#  ('producers', 366),
#  ('list', 366),
#  ('team', 366),
#  ('eventually', 364),
#  ('tells', 364),
#  ('nowhere', 363),
#  ('weren', 363),
#  ('apart', 363),
#  ('disappointing', 363),
#  ('bother', 363),
#  ('walk', 363),
#  ('twist', 362),
#  ('honestly', 362),
#  ('dr', 362),
#  ('admit', 361),
#  ('acted', 360),
#  ('van', 360),
#  ('jack', 358),
#  ('christmas', 358),
#  ('makers', 357),
#  ('yeah', 356),
#  ('villain', 355),
#  ('kills', 355),
#  ('period', 354),
#  ('learn', 354),
#  ('island', 352),
#  ('positive', 352),
#  ('release', 352),
#  ('realize', 352),
#  ('slasher', 352),
#  ('missing', 351),
#  ('e', 351),
#  ('concept', 351),
#  ('subject', 350),
#  ('expecting', 350),
#  ('herself', 350),
#  ('stick', 349),
#  ('fi', 349),
#  ('quickly', 349),
#  ('f', 348),
#  ('disappointment', 348),
#  ('soundtrack', 348),
#  ('casting', 348),
#  ('previous', 347),
#  ('simple', 347),
#  ('doctor', 347),
#  ('c', 346),
#  ('hands', 346),
#  ('surprise', 346),
#  ('value', 346),
#  ('dog', 346),
#  ('leaves', 345),
#  ('sci', 345),
#  ('peter', 345),
#  ('note', 345),
#  ('somewhere', 345),
#  ('suddenly', 344),
#  ('future', 343),
#  ('painful', 343),
#  ('form', 343),
#  ('ways', 343),
#  ('certain', 343),
#  ('redeeming', 342),
#  ('shoot', 342),
#  ('effect', 341),
#  ('ended', 341),
#  ('accent', 339),
#  ('japanese', 339),
#  ('utterly', 338),
#  ('begins', 338),
#  ('grade', 338),
#  ('project', 338),
#  ('york', 336),
#  ('biggest', 336),
#  ('difficult', 336),
#  ('spend', 336),
#  ('break', 336),
#  ('th', 336),
#  ('creepy', 335),
#  ('bottom', 334),
#  ('front', 334),
#  ('truth', 333),
#  ('rate', 333),
#  ('deal', 332),
#  ('outside', 332),
#  ('today', 332),
#  ('surprised', 331),
#  ('america', 331),
#  ('computer', 331),
#  ('relationship', 330),
#  ('create', 329),
#  ('fighting', 329),
#  ('among', 327),
#  ('crew', 326),
#  ('parents', 326),
#  ('talented', 326),
#  ('street', 326),
#  ('disney', 326),
#  ('towards', 324),
#  ('reasons', 323),
#  ('considering', 323),
#  ('episodes', 323),
#  ('indeed', 323),
#  ('interested', 323),
#  ('sick', 323),
#  ('cause', 322),
#  ('situation', 322),
#  ('features', 322),
#  ('wonderful', 321),
#  ('crime', 320),
#  ('basic', 319),
#  ('supporting', 319),
#  ('naked', 319),
#  ('became', 319),
#  ('speak', 319),
#  ('channel', 319),
#  ('store', 319),
#  ('earlier', 318),
#  ('co', 317),
#  ('joe', 317),
#  ('particular', 317),
#  ('hair', 317),
#  ('vampire', 317),
#  ('agree', 315),
#  ('mentioned', 315),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word, count in tqdm(total_counts.most_common()):
    if count > 100:
        pos_neg_ratio = positive_counts[word] / float(negative_counts[word] + 1)
        pos_neg_ratios[word] = pos_neg_ratio
# Out:
# HBox(children=(FloatProgress(value=0.0, max=74074.0), HTML(value='')))

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0663576902344554
# Pos-to-neg ratio for 'amazing' = 4.171328671328672
# Pos-to-neg ratio for 'terrible' = 0.18175895765472314

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
pos_neg_ratios_copy = pos_neg_ratios.copy()
for word, ratio in tqdm(pos_neg_ratios_copy.most_common()):
    pos_neg_ratios[word] = np.log(ratio)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4576.0), HTML(value='')))

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.06424881377124628
# Pos-to-neg ratio for 'amazing' = 1.4282346112780635
# Pos-to-neg ratio for 'terrible' = -1.705073878199932

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.337538079701318),
#  ('paulie', 4.151039905898646),
#  ('ratso', 3.3463891451671604),
#  ('felix', 3.186352633162641),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.80672172860924),
#  ('mildred', 2.6567569067146595),
#  ('sg', 2.6026896854443837),
#  ('cypher', 2.5649493574615367),
#  ('flawless', 2.5572273113676265),
#  ('gandhi', 2.538973871058276),
#  ('victoria', 2.512305623976115),
#  ('voight', 2.3848231912310176),
#  ('superbly', 2.3550315683665883),
#  ('wang', 2.312535423847214),
#  ('sopranos', 2.2472349979108808),
#  ('kidman', 2.236833715431265),
#  ('perfection', 2.204145020180793),
#  ('powell', 2.1722232751308024),
#  ('election', 2.1498223384416355),
#  ('astaire', 2.0959708436310462),
#  ('vivid', 1.366091653802371),
#  ('shines', 1.363304842895192),
#  ('cleverly', 1.3621968095408301),
#  ('poignant', 1.3449091449570363),
#  ('cole', 1.34223437132586),
#  ('innocence', 1.3378419777339439),
#  ('overlooked', 1.33500106673234),
#  ('unfolds', 1.33500106673234),
#  ('cagney', 1.3249254147435985),
#  ('remarkable', 1.3170499489449068),
#  ('titanic', 1.3164507877526264),
#  ('stunning', 1.3133875903118029),
#  ('mann', 1.3121863889661687),
#  ('crafted', 1.308332819650179),
#  ('blake', 1.2992829841302609),
#  ('portrait', 1.2966822024302034),
#  ('powerful', 1.2961432641255932),
#  ('barbara', 1.2931005842219434),
#  ('thief', 1.2893524159276601),
#  ('gentle', 1.289130612666243),
#  ('ralph', 1.2888390249691777),
#  ('carol', 1.2878542883066382),
#  ('favourite', 1.2857234543446285),
#  ('ensemble', 1.2840155119994725),
#  ('winters', 1.2833463918674481),
#  ('rural', 1.2788741124990537),
#  ('gritty', 1.275362800412609),
#  ('favorite', 1.2726971833961853),
#  ('lukas', 1.2645974261423707),
#  ('seasons', 1.2593347336586025),
#  ('brooklyn', 1.2584609896100056),
#  ('panic', 1.257676983297797),
#  ('riveting', 1.252762968495368),
#  ('holly', 1.252762968495368),
#  ('daniel', 1.2503387248838616),
#  ('haunting', 1.2502535568899422),
#  ('bond', 1.249185147147484),
#  ('tony', 1.2438564276791648),
#  ('brilliant', 1.2435194096118067),
#  ('kelly', 1.2428126376422),
#  ('recommended', 1.2399048135519992),
#  ('perfect', 1.234518856674756),
#  ('draws', 1.2335316065674804),
#  ('notch', 1.2296405510745139),
#  ('garbo', 1.2286654169163074),
#  ('nominated', 1.2269217373114807),
#  ('burns', 1.2264456601779945),
#  ('subtle', 1.2227149861356765),
#  ('philip', 1.2192402764567245),
#  ('alexander', 1.2153365629762511),
#  ('von', 1.2039728043259361),
#  ('emotions', 1.2019299026961356),
#  ('appreciated', 1.199964782928397),
#  ('perfectly', 1.1959653701022348),
#  ('rare', 1.1903671522701573),
#  ('highly', 1.1858088336982648),
#  ('june', 1.1845547184688343),
#  ('fabulous', 1.16857087727502),
#  ('consequences', 1.1631508098056809),
#  ('solo', 1.1631508098056809),
#  ('troubled', 1.1597667118214403),
#  ('terrifying', 1.1582043858703552),
#  ('today', 1.1578816971256691),
#  ('loved', 1.1562553630128685),
#  ('davis', 1.1553888044701917),
#  ('depression', 1.1541821398229204),
#  ('nicole', 1.1526795099383853),
#  ('bands', 1.1505720275988207),
#  ('courage', 1.148622709242771),
#  ('daughters', 1.1470646720540565),
#  ('stellar', 1.1451323043030026),
#  ('journey', 1.1439458299696308),
#  ('inspiring', 1.1438688802562305),
#  ('contrast', 1.1373983137032662),
#  ('awesome', 1.1372271247958892),
#  ('ideal', 1.1349799328389845),
#  ('carrie', 1.1314021114911006),
#  ('hong', 1.1295745142720766),
#  ('ned', 1.127811443360372),
#  ('intense', 1.1274951628168957),
#  ('prince', 1.1270117631898076),
#  ('unique', 1.1180303745252111),
#  ('norman', 1.116469906068116),
#  ('rival', 1.11365016603265),
#  ('sensitive', 1.1126970285498485),
#  ('pitt', 1.1118575154181303),
#  ('inventive', 1.1104467463151124),
#  ('provides', 1.1093075777848576),
#  ('smooth', 1.1080910326226534),
#  ('stallone', 1.1080910326226534),
#  ('dave', 1.1078289437730338),
#  ('dramas', 1.1071229783360184),
#  ('everyday', 1.1059923959657323),
#  ('louis', 1.1035022739623015),
#  ('ann', 1.0986122886681098),
#  ('giallo', 1.0986122886681098),
#  ('austen', 1.0986122886681098),
#  ('adorable', 1.0986122886681098),
#  ('tragic', 1.0950973465606653),
#  ('rose', 1.0942166771950717),
#  ('con', 1.0928485839513595),
#  ('curtis', 1.0895624531481918),
#  ('fay', 1.0881409888008142),
#  ('hooked', 1.0818051703517284),
#  ('kung', 1.0811445956277188),
#  ('happiness', 1.0784095813505903),
#  ('sandra', 1.0782034170369026),
#  ('glorious', 1.076139432816051),
#  ('affect', 1.072636802264849),
#  ('helps', 1.0718548394985603),
#  ('spectacular', 1.0700389162240538),
#  ('achievement', 1.0696247517948574),
#  ('blend', 1.067840630001356),
#  ('bettie', 1.0663514264498881),
#  ('fascinating', 1.065326311034643),
#  ('glover', 1.0647107369924282),
#  ('leo', 1.0622446444972349),
#  ('incredible', 1.0601460078403135),
#  ('dentist', 1.057112557761357),
#  ('beauty', 1.0546491652469936),
#  ('widow', 1.051544777810124),
#  ('recognition', 1.0479685558493548),
#  ('dalton', 1.0479685558493548),
#  ('mature', 1.0449081096962487),
#  ('lovable', 1.0414538748281612),
#  ('shy', 1.0414538748281612),
#  ('greatest', 1.040903971047463),
#  ('cinderella', 1.039613947906154),
#  ('brazil', 1.0360919316867758),
#  ('portrayal', 1.034986592787898),
#  ('vengeance', 1.034896474282002),
#  ('kyle', 1.034896474282002),
#  ('secrets', 1.0275163669843794),
#  ('carries', 1.0266387890430204),
#  ('essence', 1.0258529343856813),
#  ('facing', 1.0245043165143877),
#  ('creates', 1.0216512475319812),
#  ('definite', 1.0216512475319812),
#  ('stanley', 1.0208345876254254),
#  ('vhs', 1.0161360668438713),
#  ('awe', 1.0147308046874077),
#  ('passionate', 1.0147308046874077),
#  ('princess', 1.012998535945118),
#  ('cowboy', 1.0092671883322597),
#  ('deeply', 1.0078058407099284),
#  ('unexpected', 1.0068047394149868),
#  ('aunt', 1.0064418288684527),
#  ('jimmy', 1.0061094096848047),
#  ('mysteries', 1.0055218656020977),
#  ('thoughtful', 1.0021520224805474),
#  ('satisfying', 1.001762462678192),
#  ('spy', 1.0001722158548572),
#  ('guilt', 0.9985288301111273),
#  ('eerie', 0.9959581346080264),
#  ('beautiful', 0.9940516359335771),
#  ('comfortable', 0.9921288082656595),
#  ('lifestyle', 0.9921288082656595),
#  ('robinson', 0.9894129967031178),
#  ('enterprise', 0.9894129967031178),
#  ('craig', 0.9873866535578852),
#  ('solid', 0.9866072302916149),
#  ('midnight', 0.9862493204810654),
#  ('triumph', 0.9844989819006886),
#  ('anime', 0.9808292530117262),
#  ('walter', 0.9808292530117262),
#  ('grim', 0.9808292530117262),
#  ('waters', 0.7859289140109116),
#  ('highest', 0.7859289140109116),
#  ('paris', 0.7858378434767199),
#  ('effectively', 0.7841189587656721),
#  ('tap', 0.7841189587656721),
#  ('smith', 0.7839855809728766),
#  ('india', 0.7814397877056235),
#  ('conventional', 0.7812544480702122),
#  ('society', 0.7798155632056191),
#  ('fresh', 0.779531794758766),
#  ('verhoeven', 0.7790896103606699),
#  ('apartment', 0.778391460429555),
#  ('australia', 0.7777045685880083),
#  ('streets', 0.7771471549726836),
#  ('jim', 0.7765287894989963),
#  ('steals', 0.7731898882334817),
#  ('elderly', 0.7731898882334817),
#  ('frank', 0.772699812261899),
#  ('achieved', 0.7716187960014406),
#  ('relationships', 0.7701082216960737),
#  ('edge', 0.7697543020321422),
#  ('simple', 0.7692031719896605),
#  ('magic', 0.767680232422512),
#  ('relationship', 0.767363045037233),
#  ('blob', 0.7672551527136672),
#  ('morris', 0.7640989165322297),
#  ('simon', 0.7628805185746205),
#  ('animated', 0.7617454969026975),
#  ('master', 0.7609197956416673),
#  ('tear', 0.7608058290337602),
#  ('handsome', 0.7604508624560519),
#  ('trek', 0.7598385550586174),
#  ('touches', 0.7593965661011459),
#  ('succeeds', 0.7587444630457586),
#  ('performances', 0.7574924836503498),
#  ('dreams', 0.7568629949460531),
#  ('covers', 0.756326082181477),
#  ('forbidden', 0.7537718023763802),
#  ('maria', 0.752739277762191),
#  ('owner', 0.7518306823880355),
#  ('complaint', 0.7514160886839212),
#  ('romantic', 0.7512939587375064),
#  ('fu', 0.7505580877732844),
#  ('nevertheless', 0.750305594399894),
#  ('emotional', 0.7492366472109889),
#  ('confidence', 0.7487170317147561),
#  ('blues', 0.7487170317147561),
#  ('hart', 0.7487170317147561),
#  ('nowadays', 0.7472144018302211),
#  ('unsettling', 0.7472144018302211),
#  ('tale', 0.7462570058738937),
#  ('greatly', 0.7462570058738937),
#  ('gothic', 0.7439195059333684),
#  ('anger', 0.742627237823315),
#  ('columbo', 0.742627237823315),
#  ('che', 0.742627237823315),
#  ('endearing', 0.7410032017375805),
#  ('golden', 0.7404000654104909),
#  ('accomplished', 0.7386095546367027),
#  ('supporting', 0.7374630643344563),
#  ('rain', 0.7369498032183381),
#  ('exploration', 0.7363193524251541),
#  ('childhood', 0.7358721252262866),
#  ('strikes', 0.7348198769605134),
#  ('magical', 0.7339691750802005),
#  ('hatred', 0.7339691750802005),
#  ('impressed', 0.7326780193165805),
#  ('awards', 0.7325889126112419),
#  ('concert', 0.7316134613877414),
#  ('best', 0.7300816807529255),
#  ('patrick', 0.7295148247308201),
#  ('sunshine', 0.7290791897860087),
#  ('emotionally', 0.7274362540385775),
#  ('brooks', 0.7270487322356267),
#  ('eccentric', 0.726669872598589),
#  ('depiction', 0.7259370033829363),
#  ('atmosphere', 0.7227789781663164),
#  ('france', 0.7224747956544653),
#  ('develops', 0.7221347174331975),
#  ('advanced', 0.7221347174331975),
#  ('paul', 0.7214955355642004),
#  ('disappoint', 0.7213180575266416),
#  ('pet', 0.720926744667021),
#  ('identity', 0.719673934893374),
#  ('fine', 0.6091674599270693),
#  ('doc', 0.6090640633494039),
#  ('quirky', 0.6088060321261943),
#  ('pit', 0.6085897925318823),
#  ('lewis', 0.6078825289052572),
#  ('dealt', 0.6077873316087886),
#  ('refuses', 0.6061358035703155),
#  ('kubrick', 0.6061358035703155),
#  ('kingdom', 0.6061358035703155),
#  ('brad', 0.6047362232158923),
#  ('providing', 0.6041996945434491),
#  ('mexico', 0.6021754023542185),
#  ('pushing', 0.6021754023542185),
#  ('daring', 0.6021754023542185),
#  ('brady', 0.6015799870344548),
#  ('french', 0.6007738604289301),
#  ('relations', 0.5991182309116689),
#  ('australian', 0.5989599655002442),
#  ('contemporary', 0.5984392290183264),
#  ('tradition', 0.5978370007556204),
#  ('nature', 0.5971041315399678),
#  ('offers', 0.5949551543807315),
#  ('surprises', 0.5947071077466928),
#  ('dick', 0.5944123398742563),
#  ('bound', 0.5942072327050417),
#  ('animation', 0.5924654569537096),
#  ('job', 0.590851331720022),
#  ('introduces', 0.590493026499862),
#  ('bears', 0.5897688261061103),
#  ('timing', 0.5894687510851038),
#  ('always', 0.5892647332492886),
#  ('provided', 0.5891574670358977),
#  ('joseph', 0.589077820665739),
#  ('psychological', 0.5888343339345626),
#  ('william', 0.5877866649021191),
#  ('grow', 0.5877866649021191),
#  ('visually', 0.5866637001574952),
#  ('peace', 0.5863792051342392),
#  ('nazi', 0.5863792051342392),
#  ('true', 0.5854071277888537),
#  ('aging', 0.5852582185487603),
#  ('disc', 0.5831462853456169),
#  ('images', 0.5830219149704798),
#  ('colonel', 0.5826053061601215),
#  ('inner', 0.58122926435596),
#  ('grand', 0.5811735090104017),
#  ('pays', 0.5798184952529422),
#  ('twists', 0.5795924810130829),
#  ('claire', 0.5792029212107276),
#  ('share', 0.5787368293822011),
#  ('york', 0.5785120041828459),
#  ('hearts', 0.5776342934381009),
#  ('war', 0.5773153650348236),
#  ('family', 0.5771905392706238),
#  ('satisfied', 0.5768873744440833),
#  ('struggles', 0.5764229062518039),
#  ('mainstream', 0.5753641449035618),
#  ('fashioned', 0.5753641449035618),
#  ('heroic', 0.5753641449035618),
#  ('believable', 0.5749285099587503),
#  ('helen', 0.5742859776832165),
#  ('masks', 0.5738004229273791),
#  ('performing', 0.5730028687178821),
#  ('pre', 0.5712573629509085),
#  ('received', 0.5705448584676129),
#  ('mouse', 0.5705448584676129),
#  ('charismatic', 0.5697681593994407),
#  ('hall', 0.5695332245927687),
#  ('overcome', 0.5690945318899664),
#  ('personalities', 0.5685047353526688),
#  ('each', 0.5672786606809918),
#  ('experiences', 0.5667332557042867),
#  ('rebel', 0.5663954749208014),
#  ('young', 0.5663206050072412),
#  ('gangster', 0.5661474897986379),
#  ('world', 0.5660799345553119),
#  ('james', 0.5658361386519072),
#  ('knowing', 0.5651868329848782),
#  ('describes', 0.5630940523117475),
#  ('falk', 0.5627853626967018),
#  ('fox', 0.5617457141932476),
#  ('dream', 0.5616840409994817),
#  ('superior', 0.5607957290752713),
#  ('criticism', 0.5596157879354227),
#  ('ward', 0.5596157879354227),

#  ('prom', -2.3608540011180215),
#  ('drivel', -2.3353749158170367),
#  ('lousy', -2.32949254591397),
#  ('worst', -2.30760842612627),
#  ('laughable', -2.2911563971704227),
#  ('wasting', -2.257849199152654),
#  ('remotely', -2.2300144001592104),
#  ('crocodile', -2.2064412324411435),
#  ('poorly', -2.1972245773362196),
#  ('awful', -2.1880659557905364),
#  ('embarrassment', -2.15598161880217)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros([1, vocab_size])

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'inflammatory': 1,
#  'hunter': 2,
#  'arnetia': 3,
#  'pedophiles': 4,
#  'reaffirms': 5,
#  'jurisprudence': 6,
#  'springit': 7,
#  'reportedly': 8,
#  'price': 9,
#  'squib': 10,
#  'kwouk': 11,
#  'located': 12,
#  'disinvite': 13,
#  'kareesha': 14,
#  'amicable': 15,
#  'hexing': 16,
#  'koji': 17,
#  'killed': 18,
#  'various': 19,
#  'anniyan': 20,
#  'heidi': 21,
#  'apoplectic': 22,
#  'shipments': 23,
#  'laid': 24,
#  'lanka': 25,
#  'lennon': 26,
#  'scary': 27,
#  'humpdorama': 28,
#  'myerson': 29,
#  'vampyros': 30,
#  'hasta': 31,
#  'poste': 32,
#  'smokingly': 33,
#  'disclosures': 34,
#  'violently': 35,
#  'winterly': 36,
#  'ingenue': 37,
#  'obliged': 38,
#  'squashy': 39,
#  'maritally': 40,
#  'nearside': 41,
#  'paredes': 42,
#  'lookouts': 43,
#  'lennie': 44,
#  'permissable': 45,
#  'budjet': 46,
#  'byniarski': 47,
#  'lurene': 48,
#  'roger': 49,
#  'planetary': 50,
#  'plunk': 51,
#  'ennobling': 52,
#  'encroachments': 53,
#  'falvia': 54,
#  'rather': 55,
#  'buscemi': 56,
#  'blaster': 57,
#  'larkin': 58,
#  'teacher': 59,
#  'crypt': 60,
#  'mirrormask': 61,
#  'bensen': 62,
#  'capture': 63,
#  'actorsi': 64,
#  'bonfire': 65,
#  'mesmerizing': 66,
#  'henshall': 67,
#  'obliterating': 68,
#  'melodies': 69,
#  'boingo': 70,
#  'decrescendos': 71,
#  'structural': 72,
#  'leatherheads': 73,
#  'synapses': 74,
#  'ceilings': 75,
#  'slacked': 76,
#  'mckeever': 77,
#  'mollify': 78,
#  'priya': 79,
#  'primadonna': 80,
#  'genuis': 81,
#  'liswood': 82,
#  'concepts': 83,
#  'hopalong': 84,
#  'gaga': 85,
#  'stocky': 86,
#  'hurls': 87,
#  'fulgencio': 88,
#  'idiocies': 89,
#  'patronised': 90,
#  'stallion': 91,
#  'tools': 92,
#  'metoo': 93,
#  'alicia': 94,
#  'vaugn': 95,
#  'seduce': 96,
#  'lupinesque': 97,
#  'poser': 98,
#  'borradaile': 99,
#  'harvery': 100,
#  'hardass': 101,
#  'benella': 102,
#  'staleness': 103,
#  'pontificate': 104,
#  'lobs': 105,
#  'colwell': 106,
#  'assailant': 107,
#  'mosbey': 108,
#  'couch': 109,
#  'vlog': 110,
#  'grills': 111,
#  'botcher': 112,
#  'clerk': 113,
#  'perchance': 114,
#  'feitshans': 115,
#  'stimulants': 116,
#  'rakowsky': 117,
#  'scctm': 118,
#  'unhumorous': 119,
#  'jeb': 120,
#  'psychopathia': 121,
#  'base': 122,
#  'lumberjack': 123,
#  'refuge': 124,
#  'keener': 125,
#  'tenku': 126,
#  'humble': 127,
#  'reputable': 128,
#  'cockfight': 129,
#  'frwl': 130,
#  'dynamite': 131,
#  'reisman': 132,
#  'sluizer': 133,
#  'defalting': 134,
#  'femininity': 135,
#  'airliners': 136,
#  'mccabe': 137,
#  'gabriel': 138,
#  'wuhrer': 139,
#  'precept': 140,
#  'gelatinous': 141,
#  'hanky': 142,
#  'battleship': 143,
#  'daffy': 144,
#  'youssef': 145,
#  'toly': 146,
#  'coles': 147,
#  'singularity': 148,
#  'alvin': 149,
#  'bridges': 150,
#  'maids': 151,
#  'physicalizes': 152,
#  'speaker': 153,
#  'dreads': 154,
#  'kinnair': 155,
#  'brighten': 156,
#  'emission': 157,
#  'presence': 158,
#  'bandaras': 159,
#  'umetsu': 160,
#  'servo': 161,
#  'mindgames': 162,
#  'originate': 163,
#  'elem': 164,
#  'woodcuts': 165,
#  'breckenridge': 166,
#  'renaissance': 167,
#  'turgid': 168,
#  'treating': 169,
#  'burgess': 170,
#  'palmer': 171,
#  'buick': 172,
#  'generic': 173,
#  'araki': 174,
#  'aftereffects': 175,
#  'psychosexually': 176,
#  'burghoff': 177,
#  'hitler': 178,
#  'venom': 179,
#  'wacthing': 180,
#  'debts': 181,
#  'costy': 182,
#  'chandler': 183,
#  'probation': 184,
#  'auberjonois': 185,
#  'paneled': 186,
#  'undressing': 187,
#  'hearts': 188,
#  'cycs': 189,
#  'flute': 190,
#  'nepalese': 191,
#  'tournament': 192,
#  'sabbath': 193,
#  'popularist': 194,
#  'butchest': 195,
#  'merlet': 196,
#  'security': 197,
#  'yawahada': 198,
#  'masterfully': 199,
#  'dusted': 200,
#  'yamashita': 201,
#  'lake': 202,
#  'retailers': 203,
#  'teegra': 204,
#  'grieved': 205,
#  'exoskeleton': 206,
#  'bronchitis': 207,
#  'lapel': 208,
#  'jodedores': 209,
#  'masako': 210,
#  'puritans': 211,
#  'detaining': 212,
#  'britten': 213,
#  'garberina': 214,
#  'lis': 215,
#  'calson': 216,
#  'peavey': 217,
#  'stingers': 218,
#  'brackett': 219,
#  'ark': 220,
#  'prompting': 221,
#  'johannesburg': 222,
#  'autonomy': 223,
#  'eminating': 224,
#  'morgon': 225,
#  'persiflage': 226,
#  'raisingly': 227,
#  'berlins': 228,
#  'sha': 229,
#  'garcadiego': 230,
#  'attaches': 231,
#  'coverbox': 232,
#  'phyton': 233,
#  'vieira': 234,
#  'pretext': 235,
#  'icb': 236,
#  'pertains': 237,
#  'sudser': 238,
#  'sulley': 239,
#  'implications': 240,
#  'toplined': 241,
#  'perceptive': 242,
#  'aapke': 243,
#  'toothless': 244,
#  'silencers': 245,
#  'dork': 246,
#  'sufferes': 247,
#  'tristesse': 248,
#  'hahaha': 249,
#  'represses': 250,
#  'overlit': 251,
#  'vance': 252,
#  'hippo': 253,
#  'aykroyd': 254,
#  'conservative': 255,
#  'shortens': 256,
#  'howzat': 257,
#  'toland': 258,
#  'participated': 259,
#  'adelle': 260,
#  'jeopardized': 261,
#  'chitty': 262,
#  'declaration': 263,
#  'photogenic': 264,
#  'baer': 265,
#  'freelancing': 266,
#  'eurovision': 267,
#  'magsel': 268,
#  'suggesting': 269,
#  'oooooozzzzzzed': 270,
#  'familial': 271,
#  'hipster': 272,
#  'persistent': 273,
#  'worthing': 274,
#  'harbors': 275,
#  'thall': 276,
#  'leoncavallo': 277,
#  'graininess': 278,
#  'obligate': 279,
#  'derisive': 280,
#  'innapropriate': 281,
#  'yez': 282,
#  'barmy': 283,
#  'shorter': 284,
#  'talkes': 285,
#  'rickmansworth': 286,
#  'putting': 287,
#  'viscontis': 288,
#  'notise': 289,
#  'waterston': 290,
#  'postmortem': 291,
#  'ahhh': 292,
#  'raindrops': 293,
#  'bookings': 294,
#  'parmistan': 295,
#  'minutia': 296,
#  'scowls': 297,
#  'torso': 298,
#  'handkerchief': 299,
#  'enriching': 300,
#  'danced': 301,
#  'pat': 302,
#  'erendira': 303,
#  'rehman': 304,
#  'manghattan': 305,
#  'staffer': 306,
#  'watchtower': 307,
#  'andrus': 308,
#  'cus': 309,
#  'stigma': 310,
#  'ahah': 311,
#  'christened': 312,
#  'legislation': 313,
#  'steve': 314,
#  'maciste': 315,
#  'pedantic': 316,
#  'ganged': 317,
#  'ferland': 318,
#  'swiped': 319,
#  'obs': 320,
#  'extraordinaire': 321,
#  'rumore': 322,
#  'twats': 323,
#  'newstart': 324,
#  'unprincipled': 325,
#  'jaundiced': 326,
#  'majors': 327,
#  'gopher': 328,
#  'twist': 329,
#  'decimals': 330,
#  'mechanical': 331,
#  'nonethelss': 332,
#  'whitty': 333,
#  'trios': 334,
#  'gabba': 335,
#  'quake': 336,
#  'nada': 337,
#  'innocence': 338,
#  'calendar': 339,
#  'yarn': 340,
#  'isdon': 341,
#  'hoosier': 342,
#  'kyd': 343,
#  'complicated': 344,
#  'nonaquatic': 345,
#  'nature': 346,
#  'pivot': 347,
#  'stylisation': 348,
#  'tetsuo': 349,
#  'answered': 350,
#  'ratty': 351,
#  'banshee': 352,
#  'drippingly': 353,
#  'eamonn': 354,
#  'trout': 355,
#  'undergoes': 356,
#  'simpering': 357,
#  'happier': 358,
#  'croydon': 359,
#  'prep': 360,
#  'coppery': 361,
#  'armies': 362,
#  'wear': 363,
#  'gossett': 364,
#  'stripe': 365,
#  'catacombs': 366,
#  'waffled': 367,
#  'simulating': 368,
#  'millan': 369,
#  'provincetown': 370,
#  'bosomy': 371,
#  'largesse': 372,
#  'roadhouse': 373,
#  'neve': 374,
#  'suncoast': 375,
#  'plympton': 376,
#  'miasma': 377,
#  'pinchers': 378,
#  'scammed': 379,
#  'inexpertly': 380,
#  'floudering': 381,
#  'nonchalant': 382,
#  'tribes': 383,
#  'dividend': 384,
#  'freindship': 385,
#  'bees': 386,
#  'worsle': 387,
#  'gribbon': 388,
#  'snow': 389,
#  'coded': 390,
#  'steege': 391,
#  'pazo': 392,
#  'mantegna': 393,
#  'eggert': 394,
#  'parris': 395,
#  'stettner': 396,
#  'vestige': 397,
#  'ladislav': 398,
#  'responses': 399,
#  'blindsided': 400,
#  'afterlives': 401,
#  'luster': 402,
#  'kunst': 403,
#  'cretinous': 404,
#  'midlands': 405,
#  'donned': 406,
#  'glavas': 407,
#  'discernible': 408,
#  'fads': 409,
#  'wodehouses': 410,
#  'wheelers': 411,
#  'fattened': 412,
#  'icicle': 413,
#  'manzil': 414,
#  'klinghoffer': 415,
#  'undercooked': 416,
#  'selectivity': 417,
#  'slauther': 418,
#  'bednob': 419,
#  'exuding': 420,
#  'withstands': 421,
#  'independents': 422,
#  'iiiiii': 423,
#  'depend': 424,
#  'cicatillo': 425,
#  'tantrapur': 426,
#  'reported': 427,
#  'definate': 428,
#  'manhole': 429,
#  'shacked': 430,
#  'eaton': 431,
#  'falklands': 432,
#  'ryall': 433,
#  'nakamura': 434,
#  'awkward': 435,
#  'uncomplicated': 436,
#  'balrog': 437,
#  'gauri': 438,
#  'dim': 439,
#  'broiler': 440,
#  'coif': 441,
#  'bedchamber': 442,
#  'acclimate': 443,
#  'milwaukee': 444,
#  'hedonist': 445,
#  'slovene': 446,
#  'sabotage': 447,
#  'unhooking': 448,
#  'lawful': 449,
#  'proportioned': 450,
#  'notepad': 451,
#  'satellites': 452,
#  'gratification': 453,
#  'teletypes': 454,
#  'pomeranian': 455,
#  'spawns': 456,
#  'mediators': 457,
#  'stinkeye': 458,
#  'lundgren': 459,
#  'frmann': 460,
#  'perseus': 461,
#  'connell': 462,
#  'manfredini': 463,
#  'anouska': 464,
#  'luiz': 465,
#  'gourgous': 466,
#  'plausibly': 467,
#  'caspar': 468,
#  'zen': 469,
#  'stratham': 470,
#  'logs': 471,
#  'matronly': 472,
#  'win': 473,
#  'slappings': 474,
#  'peking': 475,
#  'verst': 476,
#  'buffa': 477,
#  'kosturica': 478,
#  'donaldson': 479,
#  'backyard': 480,
#  'faintly': 481,
#  'incapacitates': 482,
#  'taster': 483,
#  'mengele': 484,
#  'berkinsale': 485,
#  'meaneys': 486,
#  'katanas': 487,
#  'unkwown': 488,
#  'irons': 489,
#  'loudspeakers': 490,
#  'fetishwear': 491,
#  'breakable': 492,
#  'backbone': 493,
#  'kudos': 494,
#  'telekinesis': 495,
#  'breathlessly': 496,
#  'bernard': 497,
#  'purpose': 498,
#  'indelibly': 499,
#  'paces': 500,
#  'doreen': 501,
#  'investments': 502,
#  'glints': 503,
#  'engagements': 504,
#  'blithering': 505,
#  'embraceable': 506,
#  'tatty': 507,
#  'jacked': 508,
#  'equals': 509,
#  'situation': 510,
#  'affiliation': 511,
#  'callipygian': 512,
#  'senses': 513,
#  'sensical': 514,
#  'godzilla': 515,
#  'promiscuous': 516,
#  'underataker': 517,
#  'stagger': 518,
#  'abbotcostello': 519,
#  'impetuously': 520,
#  'dort': 521,
#  'norrland': 522,
#  'fuhgeddaboudit': 523,
#  'eratic': 524,
#  'dipstick': 525,
#  'dramatized': 526,
#  'mightn': 527,
#  'runaway': 528,
#  'uncontaminated': 529,
#  'hepatitis': 530,
#  'godchild': 531,
#  'itis': 532,
#  'davison': 533,
#  'pumbaa': 534,
#  'persepctive': 535,
#  'maims': 536,
#  'migratory': 537,
#  'barricade': 538,
#  'maturity': 539,
#  'agnostic': 540,
#  'khemmu': 541,
#  'goony': 542,
#  'plutocrats': 543,
#  'baton': 544,
#  'arletty': 545,
#  'subdues': 546,
#  'curio': 547,
#  'psychoanalyzes': 548,
#  'molars': 549,
#  'goggenheim': 550,
#  'aggressive': 551,
#  'gring': 552,
#  'rasche': 553,
#  'get': 554,
#  'gulagher': 555,
#  'convenience': 556,
#  'missy': 557,
#  'teammate': 558,
#  'boisterously': 559,
#  'culture': 560,
#  'imovie': 561,
#  'visa': 562,
#  'blemishes': 563,
#  'mismanagement': 564,
#  'suchet': 565,
#  'lat': 566,
#  'delving': 567,
#  'toschi': 568,
#  'stressing': 569,
#  'dither': 570,
#  'compasses': 571,
#  'martians': 572,
#  'surrey': 573,
#  'flooded': 574,
#  'dainty': 575,
#  'unpretensive': 576,
#  'pachebel': 577,
#  'fraction': 578,
#  'realism': 579,
#  'lackadaisical': 580,
#  'stranded': 581,
#  'headroom': 582,
#  'technocrats': 583,
#  'safar': 584,
#  'franks': 585,
#  'irritu': 586,
#  'bulge': 587,
#  'accounts': 588,
#  'stealthily': 589,
#  'albin': 590,
#  'guadalajara': 591,
#  'odets': 592,
#  'haa': 593,
#  'vocabulary': 594,
#  'remaindered': 595,
#  'filmmakers': 596,
#  'literalist': 597,
#  'ramonesmobile': 598,
#  'chronicle': 599,
#  'duller': 600,
#  'aditya': 601,
#  'promising': 602,
#  'prabhat': 603,
#  'marnack': 604,
#  'cardboards': 605,
#  'ambigious': 606,
#  'hertzfeldt': 607,
#  'humberfloob': 608,
#  'lankan': 609,
#  'panchamda': 610,
#  'sthf': 611,
#  'ramped': 612,
#  'giannini': 613,
#  'caffey': 614,
#  'armors': 615,
#  'sano': 616,
#  'degenerating': 617,
#  'schneider': 618,
#  'vosen': 619,
#  'hagia': 620,
#  'rawlins': 621,
#  'sedates': 622,
#  'unprovoked': 623,
#  'barem': 624,
#  'adaptations': 625,
#  'bridesmaid': 626,
#  'greenfield': 627,
#  'wallaces': 628,
#  'riemann': 629,
#  'conny': 630,
#  'reins': 631,
#  'rios': 632,
#  'portico': 633,
#  'orked': 634,
#  'borges': 635,
#  'twelfth': 636,
#  'bazar': 637,
#  'sussanah': 638,
#  'upkeep': 639,
#  'rentable': 640,
#  'fundamentals': 641,
#  'saurabh': 642,
#  'loewe': 643,
#  'beehives': 644,
#  'flemyng': 645,
#  'newman': 646,
#  'amontillado': 647,
#  'reading': 648,
#  'ludlow': 649,
#  'swallowed': 650,
#  'upwards': 651,
#  'consummation': 652,
#  'seagull': 653,
#  'ceuta': 654,
#  'ripe': 655,
#  'bandai': 656,
#  'wii': 657,
#  'intonations': 658,
#  'reichdeutch': 659,
#  'placards': 660,
#  'iwai': 661,
#  'unharmed': 662,
#  'essence': 663,
#  'midpoint': 664,
#  'smarty': 665,
#  'murderously': 666,
#  'resolve': 667,
#  'shiva': 668,
#  'northeast': 669,
#  'valli': 670,
#  'protruding': 671,
#  'csi': 672,
#  'antler': 673,
#  'despicableness': 674,
#  'merry': 675,
#  'resumes': 676,
#  'siana': 677,
#  'eds': 678,
#  'pish': 679,
#  'argumentation': 680,
#  'breakup': 681,
#  'jehennan': 682,
#  'quentine': 683,
#  'misidentification': 684,
#  'swelled': 685,
#  'periphery': 686,
#  'algernon': 687,
#  'blowingly': 688,
#  'mylne': 689,
#  'previn': 690,
#  'gratuitious': 691,
#  'seduction': 692,
#  'docile': 693,
#  'sachdev': 694,
#  'hospitable': 695,
#  'controller': 696,
#  'quieter': 697,
#  'sumptous': 698,
#  'dice': 699,
#  'farhan': 700,
#  'instrument': 701,
#  'couplea': 702,
#  'whove': 703,
#  'jos': 704,
#  'reccomened': 705,
#  'carmilla': 706,
#  'practicly': 707,
#  'barca': 708,
#  'khrystyne': 709,
#  'predictibability': 710,
#  'morphin': 711,
#  'baby': 712,
#  'expulsion': 713,
#  'raveup': 714,
#  'ransacked': 715,
#  'klowns': 716,
#  'beaker': 717,
#  'aladin': 718,
#  'bleibtreau': 719,
#  'astronomy': 720,
#  'sequenced': 721,
#  'deduces': 722,
#  'hypocritic': 723,
#  'winding': 724,
#  'spoilerand': 725,
#  'pointed': 726,
#  'glimmering': 727,
#  'backgroundother': 728,
#  'macbride': 729,
#  'wrackingly': 730,
#  'disbarred': 731,
#  'mbarrassment': 732,
#  'crown': 733,
#  'inscriptions': 734,
#  'lifter': 735,
#  'paull': 736,
#  'enlightened': 737,
#  'zeb': 738,
#  'poseidon': 739,
#  'bizzare': 740,
#  'instaneously': 741,
#  'shampooing': 742,
#  'bole': 743,
#  'derived': 744,
#  'shreveport': 745,
#  'skillful': 746,
#  'paled': 747,
#  'idle': 748,
#  'smooshed': 749,
#  'nothingsome': 750,
#  'schoolers': 751,
#  'litigation': 752,
#  'agbayani': 753,
#  'wannabe': 754,
#  'hujan': 755,
#  'severeid': 756,
#  'sublety': 757,
#  'broddrick': 758,
#  'masses': 759,
#  'gaspar': 760,
#  'aristophanes': 761,
#  'mispronouncing': 762,
#  'cheungs': 763,
#  'thereof': 764,
#  'battlements': 765,
#  'parsimony': 766,
#  'unsullied': 767,
#  'wavers': 768,
#  'committee': 769,
#  'protgs': 770,
#  'delinquent': 771,
#  'hover': 772,
#  'jiggling': 773,
#  'fascim': 774,
#  'claimer': 775,
#  'considerably': 776,
#  'contorted': 777,
#  'glaswegian': 778,
#  'mayleses': 779,
#  'crododile': 780,
#  'breathable': 781,
#  'cary': 782,
#  'lordi': 783,
#  'smartest': 784,
#  'hoyt': 785,
#  'barger': 786,
#  'appereantly': 787,
#  'fetishises': 788,
#  'fantasists': 789,
#  'uncannily': 790,
#  'dbutant': 791,
#  'commissary': 792,
#  'luxemburg': 793,
#  'whic': 794,
#  'salvageable': 795,
#  'roubaix': 796,
#  'devon': 797,
#  'garrett': 798,
#  'reiner': 799,
#  'vlady': 800,
#  'disastrous': 801,
#  'materialism': 802,
#  'sequitirs': 803,
#  'blown': 804,
#  'bumper': 805,
#  'avengers': 806,
#  'starrett': 807,
#  'streaming': 808,
#  'sunbacked': 809,
#  'scantly': 810,
#  'halmark': 811,
#  'mcneice': 812,
#  'claptrap': 813,
#  'e': 814,
#  'lulling': 815,
#  'jerome': 816,
#  'wotw': 817,
#  'andreyev': 818,
#  'impurest': 819,
#  'winckler': 820,
#  'shortcut': 821,
#  'pocketing': 822,
#  'particles': 823,
#  'wader': 824,
#  'pooja': 825,
#  'academia': 826,
#  'defusing': 827,
#  'hallmarklifetime': 828,
#  'strickland': 829,
#  'saki': 830,
#  'shady': 831,
#  'socialized': 832,
#  'gwyneth': 833,
#  'kosmos': 834,
#  'portabellow': 835,
#  'hesitates': 836,
#  'soppiness': 837,
#  'securing': 838,
#  'detours': 839,
#  'discourage': 840,
#  'hooooottttttttttt': 841,
#  'johansson': 842,
#  'tamlyn': 843,
#  'pitches': 844,
#  'riedelsheimer': 845,
#  'edwina': 846,
#  'kaho': 847,
#  'faves': 848,
#  'shooted': 849,
#  'harmonise': 850,
#  'godawul': 851,
#  'acceptation': 852,
#  'estimates': 853,
#  'adapter': 854,
#  'wickerman': 855,
#  'july': 856,
#  'grainger': 857,
#  'rhymed': 858,
#  'environmentalists': 859,
#  'brillant': 860,
#  'pathologist': 861,
#  'sargasso': 862,
#  'uruguayan': 863,
#  'trowel': 864,
#  'proliferation': 865,
#  'preservatives': 866,
#  'emmerich': 867,
#  'shrews': 868,
#  'kinng': 869,
#  'barabarian': 870,
#  'twits': 871,
#  'dropping': 872,
#  'disbelieve': 873,
#  'heaps': 874,
#  'spiderman': 875,
#  'culminated': 876,
#  'brock': 877,
#  'shades': 878,
#  'function': 879,
#  'monsignor': 880,
#  'tamo': 881,
#  'travelogues': 882,
#  'stanislav': 883,
#  'rickman': 884,
#  'rabified': 885,
#  'fellner': 886,
#  'fencers': 887,
#  'crash': 888,
#  'engulfed': 889,
#  'slipper': 890,
#  'belies': 891,
#  'unloved': 892,
#  'mules': 893,
#  'blue': 894,
#  'unexplainably': 895,
#  'iraquis': 896,
#  'unachieving': 897,
#  'watchin': 898,
#  'brattiness': 899,
#  'delongpre': 900,
#  'nicknames': 901,
#  'counterweight': 902,
#  'rampages': 903,
#  'kuala': 904,
#  'multiplying': 905,
#  'obtained': 906,
#  'lifeboats': 907,
#  'juliana': 908,
#  'eu': 909,
#  'filmtage': 910,
#  'perplexed': 911,
#  'beenville': 912,
#  'crescendoing': 913,
#  'tableau': 914,
#  'kite': 915,
#  'clinging': 916,
#  'feisty': 917,
#  'ulrike': 918,
#  'nihlan': 919,
#  'sleepers': 920,
#  'hungrier': 921,
#  'halima': 922,
#  'landscape': 923,
#  'jivetalking': 924,
#  'invaders': 925,
#  'unappealing': 926,
#  'porridge': 927,
#  'bohbot': 928,
#  'worded': 929,
#  'dispositions': 930,
#  'nikki': 931,
#  'vinay': 932,
#  'plate': 933,
#  'suggestive': 934,
#  'cormans': 935,
#  'thunderously': 936,
#  'rotheroe': 937,
#  'funniest': 938,
#  'posteriors': 939,
#  'wildenbrck': 940,
#  'es': 941,
#  'erode': 942,
#  'macauley': 943,
#  'purveyors': 944,
#  'videothek': 945,
#  'conclusions': 946,
#  'careens': 947,
#  'testa': 948,
#  'bugle': 949,
#  'abbie': 950,
#  'kaylene': 951,
#  'advocacy': 952,
#  'montauk': 953,
#  'vincente': 954,
#  'kinmont': 955,
#  'stillman': 956,
#  'trailed': 957,
#  'healthily': 958,
#  'submitting': 959,
#  'awakenings': 960,
#  'livelihood': 961,
#  'anway': 962,
#  'geeeeeetttttttt': 963,
#  'bubblingly': 964,
#  'spirtas': 965,
#  'cellar': 966,
#  'pardoning': 967,
#  'execution': 968,
#  'clunky': 969,
#  'grouping': 970,
#  'frats': 971,
#  'residencia': 972,
#  'space': 973,
#  'tuileries': 974,
#  'hing': 975,
#  'perfectly': 976,
#  'moroder': 977,
#  'capita': 978,
#  'everly': 979,
#  'rodential': 980,
#  'elisa': 981,
#  'need': 982,
#  'constancy': 983,
#  'exaggeration': 984,
#  'despise': 985,
#  'vemork': 986,
#  'midsection': 987,
#  'poppy': 988,
#  'freakishly': 989,
#  'cheever': 990,
#  'togther': 991,
#  'outthere': 992,
#  'shakespearean': 993,
#  'simulate': 994,
#  'division': 995,
#  'controlled': 996,
#  'inarguably': 997,
#  'maguffin': 998,
#  'immortalize': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(' '):
        word_idx = word2index[word]
        layer_0[0, word_idx] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == 'POSITIVE':
        return 1
    elif label == 'NEGATIVE':
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".

        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.

        for review, label in zip(reviews, labels):
            for word in review.split(' '):
                review_vocab.add(word)
            label_vocab.add(label)
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
                
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for i, word in enumerate(review_vocab):
            self.word2index[word] = i
    
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for i, label in enumerate(label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.random.normal(0.0, self.input_nodes**-0.5,
                                           (self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.hidden_nodes**-0.5,
                                            (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1, input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"

        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0

        # count how many times each word is used in the given review and store the results in layer_0 
        keys = self.word2index.keys()
        for word in review.split(' '):
            if word in self.word2index:
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        if label == 'POSITIVE':
            return 1
        elif label == 'NEGATIVE':
            return 0

    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        return 1 / (1 + np.exp(-x))

    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1 - output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]

            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.

            # Input Layer
            self.update_input_layer(review)
            # Hidden Layer
            hidden_outputs = self.layer_0.dot(self.weights_0_1)
            # Output Layer
            final_outputs = self.sigmoid(hidden_outputs.dot(self.weights_1_2))
        
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.

            # output error
            error = final_outputs - self.get_target_for_label(label)
            output_error_term = error * self.sigmoid_output_2_derivative(final_outputs)

            # hidden error
            hidden_error = output_error_term.dot(self.weights_1_2.T)
            hidden_error_term = hidden_error * 1

            # Update the weights
            self.weights_1_2 -= hidden_error.T.dot(output_error_term) * self.learning_rate
            self.weights_0_1 -= self.layer_0.T.dot(hidden_error_term) * self.learning_rate
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            if(final_outputs >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(final_outputs < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
                
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
                # Run a forward pass through the network, like in the "train" function.
       
        # Input Layer
        self.update_input_layer(review.lower())
        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)
        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))

        # return label
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:18.4% Speed(reviews/sec):991.3 #Correct:105 #Tested:185 Testing Accuracy:56.7%
# Progress:37.5% Speed(reviews/sec):1012. #Correct:192 #Tested:376 Testing Accuracy:51.0%
# Progress:61.0% Speed(reviews/sec):1068. #Correct:309 #Tested:611 Testing Accuracy:50.5%
# Progress:83.3% Speed(reviews/sec):1126. #Correct:418 #Tested:834 Testing Accuracy:50.1%
# Progress:99.9% Speed(reviews/sec):1126. #Correct:493 #Tested:1000 Testing Accuracy:49.3%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):150.3 #Correct:1242 #Trained:2501 Training Accuracy:49.6%
# Progress:20.8% Speed(reviews/sec):144.1 #Correct:2511 #Trained:5001 Training Accuracy:50.2%
# Progress:31.2% Speed(reviews/sec):137.3 #Correct:3832 #Trained:7501 Training Accuracy:51.0%
# Progress:41.6% Speed(reviews/sec):136.0 #Correct:5247 #Trained:10001 Training Accuracy:52.4%
# Progress:52.0% Speed(reviews/sec):135.7 #Correct:6815 #Trained:12501 Training Accuracy:54.5%
# Progress:62.5% Speed(reviews/sec):135.8 #Correct:8499 #Trained:15001 Training Accuracy:56.6%
# Progress:72.9% Speed(reviews/sec):136.0 #Correct:10183 #Trained:17501 Training Accuracy:58.1%
# Progress:83.3% Speed(reviews/sec):133.4 #Correct:11883 #Trained:20001 Training Accuracy:59.4%
# Progress:93.7% Speed(reviews/sec):132.3 #Correct:13622 #Trained:22501 Training Accuracy:60.5%
# Progress:99.9% Speed(reviews/sec):131.9 #Correct:14657 #Trained:24000 Training Accuracy:61.0%

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):140.9 #Correct:1340 #Trained:2501 Training Accuracy:53.5%
# Progress:20.8% Speed(reviews/sec):137.2 #Correct:2858 #Trained:5001 Training Accuracy:57.1%
# Progress:31.2% Speed(reviews/sec):136.6 #Correct:4502 #Trained:7501 Training Accuracy:60.0%
# Progress:41.6% Speed(reviews/sec):136.1 #Correct:6285 #Trained:10001 Training Accuracy:62.8%
# Progress:52.0% Speed(reviews/sec):135.6 #Correct:8110 #Trained:12501 Training Accuracy:64.8%
# Progress:62.5% Speed(reviews/sec):134.5 #Correct:9944 #Trained:15001 Training Accuracy:66.2%
# Progress:72.9% Speed(reviews/sec):134.5 #Correct:11805 #Trained:17501 Training Accuracy:67.4%
# Progress:83.3% Speed(reviews/sec):134.4 #Correct:13712 #Trained:20001 Training Accuracy:68.5%
# Progress:93.7% Speed(reviews/sec):134.1 #Correct:15621 #Trained:22501 Training Accuracy:69.4%
# Progress:99.9% Speed(reviews/sec):133.9 #Correct:16789 #Trained:24000 Training Accuracy:69.9%

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):130.6 #Correct:1388 #Trained:2501 Training Accuracy:55.4%
# Progress:20.8% Speed(reviews/sec):131.8 #Correct:2956 #Trained:5001 Training Accuracy:59.1%
# Progress:31.2% Speed(reviews/sec):131.9 #Correct:4608 #Trained:7501 Training Accuracy:61.4%
# Progress:41.6% Speed(reviews/sec):131.8 #Correct:6329 #Trained:10001 Training Accuracy:63.2%
# Progress:52.0% Speed(reviews/sec):131.8 #Correct:8084 #Trained:12501 Training Accuracy:64.6%
# Progress:62.5% Speed(reviews/sec):131.7 #Correct:9851 #Trained:15001 Training Accuracy:65.6%
# Progress:72.9% Speed(reviews/sec):131.7 #Correct:11649 #Trained:17501 Training Accuracy:66.5%
# Progress:83.3% Speed(reviews/sec):132.0 #Correct:13502 #Trained:20001 Training Accuracy:67.5%
# Progress:93.7% Speed(reviews/sec):131.9 #Correct:15349 #Trained:22501 Training Accuracy:68.2%
# Progress:99.9% Speed(reviews/sec):132.1 #Correct:16492 #Trained:24000 Training Accuracy:68.7%

# %% [markdown]
# With a learning rate of `0.001`, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
